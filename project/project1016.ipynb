# %%
import os
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import cv2 as cv

import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import multilabel_confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization, concatenate
from tensorflow.keras.activations import relu, sigmoid
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.utils import plot_model, save_img
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_dir = '../input'

# %%
plant_village_dir = '/content/drive/MyDrive/plantvillage dataset'

# %%
fnames = []

for dir in os.listdir(os.path.join(plant_village_dir, 'color')):
    columns = dir.split('___')
    columns.append(dir)
    fnames.append(columns)

# %%
fnames = pd.DataFrame(fnames, columns=['Tree type', 'Disease', 'Folder'])
fnames
# Out:
#                   Tree type                               Disease  \
# 0                     Apple                            Apple_scab
# 1                     Apple                             Black_rot
# 2                     Apple                      Cedar_apple_rust
# 3                     Apple                               healthy
# 4                 Blueberry                               healthy
# 5   Cherry_(including_sour)                        Powdery_mildew
# 6   Cherry_(including_sour)                               healthy
# 7              Corn_(maize)   Cercospora_leaf_spot Gray_leaf_spot
# 8              Corn_(maize)                          Common_rust_
# 9              Corn_(maize)                  Northern_Leaf_Blight
# 10             Corn_(maize)                               healthy
# 11                    Grape                             Black_rot
# 12                    Grape                  Esca_(Black_Measles)
# 13                    Grape    Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                    Grape                               healthy
# 15                   Orange       Haunglongbing_(Citrus_greening)
# 16                    Peach                        Bacterial_spot
# 17                    Peach                               healthy
# 18             Pepper,_bell                        Bacterial_spot
# 19             Pepper,_bell                               healthy
# 20                   Potato                          Early_blight
# 21                   Potato                           Late_blight
# 22                   Potato                               healthy
# 23                Raspberry                               healthy
# 24                  Soybean                               healthy
# 25                   Squash                        Powdery_mildew
# 26               Strawberry                           Leaf_scorch
# 27               Strawberry                               healthy
# 28                   Tomato                        Bacterial_spot
# 29                   Tomato                          Early_blight
# 30                   Tomato                           Late_blight
# 31                   Tomato                             Leaf_Mold
# 32                   Tomato                    Septoria_leaf_spot
# 33                   Tomato  Spider_mites Two-spotted_spider_mite
# 34                   Tomato                           Target_Spot
# 35                   Tomato         Tomato_Yellow_Leaf_Curl_Virus
# 36                   Tomato                   Tomato_mosaic_virus
# 37                   Tomato                               healthy
#
#                                                Folder
# 0                                  Apple___Apple_scab
# 1                                   Apple___Black_rot
# 2                            Apple___Cedar_apple_rust
# 3                                     Apple___healthy
# 4                                 Blueberry___healthy
# 5            Cherry_(including_sour)___Powdery_mildew
# 6                   Cherry_(including_sour)___healthy
# 7   Corn_(maize)___Cercospora_leaf_spot Gray_leaf_...
# 8                         Corn_(maize)___Common_rust_
# 9                 Corn_(maize)___Northern_Leaf_Blight
# 10                             Corn_(maize)___healthy
# 11                                  Grape___Black_rot
# 12                       Grape___Esca_(Black_Measles)
# 13         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                                    Grape___healthy
# 15           Orange___Haunglongbing_(Citrus_greening)
# 16                             Peach___Bacterial_spot
# 17                                    Peach___healthy
# 18                      Pepper,_bell___Bacterial_spot
# 19                             Pepper,_bell___healthy
# 20                              Potato___Early_blight
# 21                               Potato___Late_blight
# 22                                   Potato___healthy
# 23                                Raspberry___healthy
# 24                                  Soybean___healthy
# 25                            Squash___Powdery_mildew
# 26                           Strawberry___Leaf_scorch
# 27                               Strawberry___healthy
# 28                            Tomato___Bacterial_spot
# 29                              Tomato___Early_blight
# 30                               Tomato___Late_blight
# 31                                 Tomato___Leaf_Mold
# 32                        Tomato___Septoria_leaf_spot
# 33      Tomato___Spider_mites Two-spotted_spider_mite
# 34                               Tomato___Target_Spot
# 35             Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 36                       Tomato___Tomato_mosaic_virus
# 37                                   Tomato___healthy

# %%
fnames.drop([4,15,23,24,25],axis=0,inplace=True)
fnames
# Out:
#                   Tree type                               Disease  \
# 0                     Apple                            Apple_scab
# 1                     Apple                             Black_rot
# 2                     Apple                      Cedar_apple_rust
# 3                     Apple                               healthy
# 5   Cherry_(including_sour)                        Powdery_mildew
# 6   Cherry_(including_sour)                               healthy
# 7              Corn_(maize)   Cercospora_leaf_spot Gray_leaf_spot
# 8              Corn_(maize)                          Common_rust_
# 9              Corn_(maize)                  Northern_Leaf_Blight
# 10             Corn_(maize)                               healthy
# 11                    Grape                             Black_rot
# 12                    Grape                  Esca_(Black_Measles)
# 13                    Grape    Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                    Grape                               healthy
# 16                    Peach                        Bacterial_spot
# 17                    Peach                               healthy
# 18             Pepper,_bell                        Bacterial_spot
# 19             Pepper,_bell                               healthy
# 20                   Potato                          Early_blight
# 21                   Potato                           Late_blight
# 22                   Potato                               healthy
# 26               Strawberry                           Leaf_scorch
# 27               Strawberry                               healthy
# 28                   Tomato                        Bacterial_spot
# 29                   Tomato                          Early_blight
# 30                   Tomato                           Late_blight
# 31                   Tomato                             Leaf_Mold
# 32                   Tomato                    Septoria_leaf_spot
# 33                   Tomato  Spider_mites Two-spotted_spider_mite
# 34                   Tomato                           Target_Spot
# 35                   Tomato         Tomato_Yellow_Leaf_Curl_Virus
# 36                   Tomato                   Tomato_mosaic_virus
# 37                   Tomato                               healthy
#
#                                                Folder
# 0                                  Apple___Apple_scab
# 1                                   Apple___Black_rot
# 2                            Apple___Cedar_apple_rust
# 3                                     Apple___healthy
# 5            Cherry_(including_sour)___Powdery_mildew
# 6                   Cherry_(including_sour)___healthy
# 7   Corn_(maize)___Cercospora_leaf_spot Gray_leaf_...
# 8                         Corn_(maize)___Common_rust_
# 9                 Corn_(maize)___Northern_Leaf_Blight
# 10                             Corn_(maize)___healthy
# 11                                  Grape___Black_rot
# 12                       Grape___Esca_(Black_Measles)
# 13         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                                    Grape___healthy
# 16                             Peach___Bacterial_spot
# 17                                    Peach___healthy
# 18                      Pepper,_bell___Bacterial_spot
# 19                             Pepper,_bell___healthy
# 20                              Potato___Early_blight
# 21                               Potato___Late_blight
# 22                                   Potato___healthy
# 26                           Strawberry___Leaf_scorch
# 27                               Strawberry___healthy
# 28                            Tomato___Bacterial_spot
# 29                              Tomato___Early_blight
# 30                               Tomato___Late_blight
# 31                                 Tomato___Leaf_Mold
# 32                        Tomato___Septoria_leaf_spot
# 33      Tomato___Spider_mites Two-spotted_spider_mite
# 34                               Tomato___Target_Spot
# 35             Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 36                       Tomato___Tomato_mosaic_virus
# 37                                   Tomato___healthy

# %%
fnames['Disease'] = fnames['Disease'].str.replace('_', ' ')
fnames['Disease'] = fnames['Disease'].str.lstrip()
fnames['Tree type'] = fnames['Tree type'].str.replace('_', ' ')
fnames['Tree type'] = fnames['Tree type'].str.lstrip()
fnames
# Out:
#                   Tree type                               Disease  \
# 0                     Apple                            Apple scab
# 1                     Apple                             Black rot
# 2                     Apple                      Cedar apple rust
# 3                     Apple                               healthy
# 5   Cherry (including sour)                        Powdery mildew
# 6   Cherry (including sour)                               healthy
# 7              Corn (maize)   Cercospora leaf spot Gray leaf spot
# 8              Corn (maize)                          Common rust
# 9              Corn (maize)                  Northern Leaf Blight
# 10             Corn (maize)                               healthy
# 11                    Grape                             Black rot
# 12                    Grape                  Esca (Black Measles)
# 13                    Grape    Leaf blight (Isariopsis Leaf Spot)
# 14                    Grape                               healthy
# 16                    Peach                        Bacterial spot
# 17                    Peach                               healthy
# 18             Pepper, bell                        Bacterial spot
# 19             Pepper, bell                               healthy
# 20                   Potato                          Early blight
# 21                   Potato                           Late blight
# 22                   Potato                               healthy
# 26               Strawberry                           Leaf scorch
# 27               Strawberry                               healthy
# 28                   Tomato                        Bacterial spot
# 29                   Tomato                          Early blight
# 30                   Tomato                           Late blight
# 31                   Tomato                             Leaf Mold
# 32                   Tomato                    Septoria leaf spot
# 33                   Tomato  Spider mites Two-spotted spider mite
# 34                   Tomato                           Target Spot
# 35                   Tomato         Tomato Yellow Leaf Curl Virus
# 36                   Tomato                   Tomato mosaic virus
# 37                   Tomato                               healthy
#
#                                                Folder
# 0                                  Apple___Apple_scab
# 1                                   Apple___Black_rot
# 2                            Apple___Cedar_apple_rust
# 3                                     Apple___healthy
# 5            Cherry_(including_sour)___Powdery_mildew
# 6                   Cherry_(including_sour)___healthy
# 7   Corn_(maize)___Cercospora_leaf_spot Gray_leaf_...
# 8                         Corn_(maize)___Common_rust_
# 9                 Corn_(maize)___Northern_Leaf_Blight
# 10                             Corn_(maize)___healthy
# 11                                  Grape___Black_rot
# 12                       Grape___Esca_(Black_Measles)
# 13         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                                    Grape___healthy
# 16                             Peach___Bacterial_spot
# 17                                    Peach___healthy
# 18                      Pepper,_bell___Bacterial_spot
# 19                             Pepper,_bell___healthy
# 20                              Potato___Early_blight
# 21                               Potato___Late_blight
# 22                                   Potato___healthy
# 26                           Strawberry___Leaf_scorch
# 27                               Strawberry___healthy
# 28                            Tomato___Bacterial_spot
# 29                              Tomato___Early_blight
# 30                               Tomato___Late_blight
# 31                                 Tomato___Leaf_Mold
# 32                        Tomato___Septoria_leaf_spot
# 33      Tomato___Spider_mites Two-spotted_spider_mite
# 34                               Tomato___Target_Spot
# 35             Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 36                       Tomato___Tomato_mosaic_virus
# 37                                   Tomato___healthy

# %%
os.mkdir('image data')

# %%
os.mkdir(os.path.join('image data', 'train'))
os.mkdir(os.path.join('image data', 'validation'))
os.mkdir(os.path.join('image data', 'test'))

# %%
train_path = os.path.join('image data/train')
val_path = os.path.join('image data/validation')
test_path = os.path.join('image data/test')

# %%
fnames['Tree type'].unique().tolist()
# Out:
# ['Apple',
#  'Cherry (including sour)',
#  'Corn (maize)',
#  'Grape',
#  'Peach',
#  'Pepper, bell',
#  'Potato',
#  'Strawberry',
#  'Tomato']

# %%
path_1 = os.path.join(train_path, 'Apple')
path_2 = os.path.join(test_path, 'Apple')
path_3 = os.path.join(val_path, 'Apple')

os.mkdir(path_1)
os.mkdir(path_2)
os.mkdir(path_3)

# %%
for disease, folder in fnames[fnames['Tree type'] == 'Apple'][['Disease', 'Folder']].values.tolist():
    # create directory to each disease
    sub_path_1 = os.path.join(path_1, disease.strip())
    sub_path_2 = os.path.join(path_2, disease.strip())
    sub_path_3 = os.path.join(path_3, disease.strip())

    os.mkdir(sub_path_1)
    os.mkdir(sub_path_2)
    os.mkdir(sub_path_3)

    # read data from source folder
    src = os.path.join(plant_village_dir, 'color', folder)
    image_count = len(os.listdir(src))
    test_img_count = image_count // 10
    val_img_count = (image_count - test_img_count) // 5
    train_img_count = image_count - (test_img_count + val_img_count)
    counts = [train_img_count, test_img_count, val_img_count]
    splits = [sub_path_1, sub_path_2, sub_path_3]

    for i in range(3):
        images = os.listdir(src)
        for j in images[:counts[i]]:
            shutil.copyfile(src=os.path.join(src, j),
                            dst=os.path.join(splits[i], j))

# %%
X = []
y = []
val_x = []
val_y = []
test_x = []
test_y = []

tree_path = os.path.join('image data/train', 'Apple')
tree_disease_types = os.listdir(tree_path)

for disease in tree_disease_types:
    img_name = os.listdir(os.path.join(tree_path, disease))

    for img in img_name:
        image_path = os.path.join(tree_path, disease, img)
        image = img_to_array(load_img(image_path, target_size=(56,56)))
        X.append(image)
        y.append([disease])

# %%
tree_path = os.path.join('image data/validation', 'Apple')
tree_disease_types = os.listdir(tree_path)

for disease in tree_disease_types:
    img_name = os.listdir(os.path.join(tree_path, disease))

    for img in img_name:
        image_path = os.path.join(tree_path, disease, img)
        image = img_to_array(load_img(image_path, target_size=(56,56)))
        val_x.append(image)
        val_y.append([disease])

# %%
tree_path = os.path.join('image data/test', 'Apple')
tree_disease_types = os.listdir(tree_path)

for disease in tree_disease_types:
    img_name = os.listdir(os.path.join(tree_path, disease))

    for img in img_name:
        image_path = os.path.join(tree_path, disease, img)
        image = img_to_array(load_img(image_path, target_size=(56,56)))
        test_x.append(image)
        test_y.append([disease])

# %%
mlb = MultiLabelBinarizer()

X = np.array(X)
val_x = np.array(val_x)
y = mlb.fit_transform(y)
val_y = mlb.transform(val_y)
test_y = mlb.transform(test_y)
test_x = np.array(test_x)/255
val_x = val_x/255
X.shape, y.shape
# Out:
# ((2286, 56, 56, 3), (2286, 4))

# %%
generator = ImageDataGenerator(rescale=1. / 255,
                               rotation_range=15,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               horizontal_flip=True,
                               vertical_flip=True
                                    )
generator.fit(X)

# %%
check_pointer = ModelCheckpoint(filepath='exp_conv_20.hdf5',
                                save_best_only=True)

early_stop = EarlyStopping(monitor='val_loss',
                           patience=30,
                           min_delta=0,
                           restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.1,
                              patience=10,
                             cooldown=5)

# %%
def inception_module(x, filter_1x1, filter_3x3_reduce, filter_3x3, filter_5x5_reduce, filter_5x5, filters_pool_proj,
                     name=None):
    # reduction layer
    conv_3x3_reducer = Conv2D(filters=filter_3x3_reduce, kernel_size=(1, 1), activation=relu, padding='same')(x)
    conv_5x5_reducer = Conv2D(filters=filter_5x5_reduce, kernel_size=(1, 1), activation=relu, padding='same')(x)
    pool_3x3 = MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same')(x)

    # extraction layer
    conv_3x3 = Conv2D(filters=filter_3x3, kernel_size=(3, 3), activation=relu, padding='same')(conv_3x3_reducer)
    conv_5x5 = Conv2D(filters=filter_5x5, kernel_size=(5, 5), activation=relu, padding='same')(conv_5x5_reducer)
    conv_1x1_proj = Conv2D(filters=filters_pool_proj, kernel_size=(1, 1), activation=relu, padding='same')(pool_3x3)

    # projection layer
    proj = Conv2D(filters=filter_1x1, kernel_size=(1, 1), activation=relu, padding='same')(x)

    # output
    x = concatenate([proj, conv_1x1_proj, conv_3x3, conv_5x5], axis=3, name=name)

    return x

# %%
exp_input = Input(shape=(56,56,3))

# conv_7x7
x = Conv2D(filters=64, kernel_size=(7,7), padding='same', activation=relu)(exp_input)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(3,3), strides=(1,1))(x)

# conv_5x5
x = Conv2D(filters=192, kernel_size=(5,5), padding='same', activation=relu)(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(3,3), strides=(1,1))(x)

# inception block 1
x = inception_module(x,
                     filter_1x1=64,
                     filter_5x5_reduce=96,
                     filter_3x3=128,
                     filter_3x3_reduce=16,
                     filter_5x5=32,
                     filters_pool_proj=32,
                     name='inception_1a')
x = inception_module(x,
                     filter_1x1=96,
                     filter_5x5_reduce=128,
                     filter_3x3=160,
                     filter_3x3_reduce=32,
                     filter_5x5=48,
                     filters_pool_proj=64,
                     name='inception_1b')

# pooling
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

# inception block 2
x = inception_module(x,
                     filter_1x1=128,
                     filter_5x5_reduce=96,
                     filter_3x3=128,
                     filter_3x3_reduce=48,
                     filter_5x5=32,
                     filters_pool_proj=32,
                     name='inception_2a')
x = inception_module(x,
                     filter_1x1=160,
                     filter_5x5_reduce=112,
                     filter_3x3=160,
                     filter_3x3_reduce=32,
                     filter_5x5=64,
                     filters_pool_proj=64,
                     name='inception_2b')
x = inception_module(x,
                     filter_1x1=192,
                     filter_5x5_reduce=128,
                     filter_3x3=128,
                     filter_3x3_reduce=48,
                     filter_5x5=64,
                     filters_pool_proj=64,
                     name='inception_2c')
x = inception_module(x,
                     filter_1x1=256,
                     filter_5x5_reduce=160,
                     filter_3x3=160,
                     filter_3x3_reduce=32,
                     filter_5x5=96,
                     filters_pool_proj=96,
                     name='inception_2d')

# pooling
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

# conv 3x3
x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

# flatten
x = Flatten()(x)

# output layer
x = Dense(units=1024, activation=relu)(x)
x = Dropout(0.5)(x)
x = Dense(units=1024, activation=relu)(x)
x = Dropout(0.5)(x)
exp_output = Dense(units=10, activation=sigmoid)(x)     # units 개수?????

exp_conv = Model(exp_input, exp_output)
exp_conv.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 56, 56, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 56, 56, 64)   9472        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 56, 56, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  max_pooling2d (MaxPooling2D)   (None, 54, 54, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 54, 54, 192)  307392      ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 54, 54, 192)  768        ['conv2d_1[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 52, 52, 192)  0          ['batch_normalization_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 52, 52, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 52, 52, 16)   3088        ['max_pooling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 52, 52, 96)   18528       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 52, 52, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 52, 52, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 52, 52, 128)  18560       ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 52, 52, 32)   76832       ['conv2d_3[0][0]']
#
#  inception_1a (Concatenate)     (None, 52, 52, 256)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 256)  0          ['inception_1a[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 52, 52, 32)   8224        ['inception_1a[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 52, 52, 128)  32896       ['inception_1a[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 52, 52, 96)   24672       ['inception_1a[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 52, 52, 64)   16448       ['max_pooling2d_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 52, 52, 160)  46240       ['conv2d_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 52, 52, 48)   153648      ['conv2d_9[0][0]']
#
#  inception_1b (Concatenate)     (None, 52, 52, 368)  0           ['conv2d_13[0][0]',
#                                                                   'conv2d_12[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 52, 52, 368)  1472       ['inception_1b[0][0]']
#  rmalization)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 26, 26, 368)  0          ['batch_normalization_2[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 26, 26, 368)  0          ['max_pooling2d_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 26, 26, 48)   17712       ['max_pooling2d_4[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 26, 26, 96)   35424       ['max_pooling2d_4[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 26, 26, 128)  47232       ['max_pooling2d_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 26, 26, 32)   11808       ['max_pooling2d_5[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 26, 26, 128)  55424       ['conv2d_14[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 26, 26, 32)   76832       ['conv2d_15[0][0]']
#
#  inception_2a (Concatenate)     (None, 26, 26, 320)  0           ['conv2d_19[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_16[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 26, 26, 320)  0          ['inception_2a[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 26, 26, 32)   10272       ['inception_2a[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 26, 26, 112)  35952       ['inception_2a[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 26, 26, 160)  51360       ['inception_2a[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 26, 26, 64)   20544       ['max_pooling2d_6[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 26, 26, 160)  46240       ['conv2d_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 26, 26, 64)   179264      ['conv2d_21[0][0]']
#
#  inception_2b (Concatenate)     (None, 26, 26, 448)  0           ['conv2d_25[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_22[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 26, 26, 448)  0          ['inception_2b[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 26, 26, 48)   21552       ['inception_2b[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 26, 26, 128)  57472       ['inception_2b[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 26, 26, 192)  86208       ['inception_2b[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 26, 26, 64)   28736       ['max_pooling2d_7[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 26, 26, 128)  55424       ['conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 26, 26, 64)   204864      ['conv2d_27[0][0]']
#
#  inception_2c (Concatenate)     (None, 26, 26, 448)  0           ['conv2d_31[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_28[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 26, 26, 448)  0          ['inception_2c[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 26, 26, 32)   14368       ['inception_2c[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 26, 26, 160)  71840       ['inception_2c[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 26, 26, 256)  114944      ['inception_2c[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 26, 26, 96)   43104       ['max_pooling2d_8[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 26, 26, 160)  46240       ['conv2d_32[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 26, 26, 96)   384096      ['conv2d_33[0][0]']
#
#  inception_2d (Concatenate)     (None, 26, 26, 608)  0           ['conv2d_37[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_34[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 26, 26, 608)  2432       ['inception_2d[0][0]']
#  rmalization)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 13, 13, 608)  0          ['batch_normalization_3[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 13, 13, 256)  1401088     ['max_pooling2d_9[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 13, 13, 256)  590080      ['conv2d_38[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 13, 13, 256)  1024       ['conv2d_39[0][0]']
#  rmalization)
#
#  max_pooling2d_10 (MaxPooling2D  (None, 7, 7, 256)   0           ['batch_normalization_4[0][0]']
#  )
#
#  conv2d_40 (Conv2D)             (None, 7, 7, 256)    590080      ['max_pooling2d_10[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 7, 7, 256)    590080      ['conv2d_40[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_41[0][0]']
#  rmalization)
#
#  max_pooling2d_11 (MaxPooling2D  (None, 4, 4, 256)   0           ['batch_normalization_5[0][0]']
#  )
#
#  conv2d_42 (Conv2D)             (None, 4, 4, 256)    590080      ['max_pooling2d_11[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 4, 4, 256)    590080      ['conv2d_42[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 4, 4, 256)   1024        ['conv2d_43[0][0]']
#  rmalization)
#
#  max_pooling2d_12 (MaxPooling2D  (None, 2, 2, 256)   0           ['batch_normalization_6[0][0]']
#  )
#
#  flatten (Flatten)              (None, 1024)         0           ['max_pooling2d_12[0][0]']
#
#  dense (Dense)                  (None, 1024)         1049600     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1024)         1049600     ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 10)           10250       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 8,920,378
# Trainable params: 8,916,378
# Non-trainable params: 4,000
# __________________________________________________________________________________________________

# %%
plot_model(exp_conv,
           to_file='baseline_conv_15_exp(VGGNet with INCEPTION).png',
           show_shapes=True,
           show_dtype=True,
           show_layer_names=True)

# %%
exp_conv.compile(optimizer=Adam(),
                   loss=binary_crossentropy,
                   metrics=[Recall(), Precision(), 'accuracy'])

history = exp_conv.fit(generator.flow(X,y, batch_size=128), 
                        epochs=500, 
                        validation_data=(val_x,val_y),
                        callbacks=[early_stop, check_pointer, reduce_lr])
# Out:
# Epoch 1/500
# 103/103 [==============================] - 111s 858ms/step - loss: 0.2498 - recall: 0.3527 - precision: 0.6464 - accuracy: 0.4968 - val_loss: 0.5449 - val_recall: 0.1862 - val_precision: 0.1234 - val_accuracy: 0.1384 - lr: 0.0010
# Epoch 2/500
# 103/103 [==============================] - 83s 809ms/step - loss: 0.1484 - recall: 0.5864 - precision: 0.8063 - accuracy: 0.6946 - val_loss: 1.6263 - val_recall: 0.0876 - val_precision: 0.0876 - val_accuracy: 0.0876 - lr: 0.0010
# Epoch 3/500
# 103/103 [==============================] - 83s 806ms/step - loss: 0.1218 - recall: 0.6769 - precision: 0.8284 - accuracy: 0.7526 - val_loss: 0.5497 - val_recall: 0.1510 - val_precision: 0.1598 - val_accuracy: 0.1519 - lr: 0.0010
# Epoch 4/500
# 103/103 [==============================] - 83s 805ms/step - loss: 0.1046 - recall: 0.7303 - precision: 0.8501 - accuracy: 0.7941 - val_loss: 0.6335 - val_recall: 0.2907 - val_precision: 0.3077 - val_accuracy: 0.2922 - lr: 0.0010
# Epoch 5/500
# 103/103 [==============================] - 84s 811ms/step - loss: 0.0903 - recall: 0.7775 - precision: 0.8662 - accuracy: 0.8213 - val_loss: 0.4764 - val_recall: 0.4187 - val_precision: 0.4590 - val_accuracy: 0.4417 - lr: 0.0010
# Epoch 6/500
# 103/103 [==============================] - 84s 812ms/step - loss: 0.0810 - recall: 0.8072 - precision: 0.8811 - accuracy: 0.8460 - val_loss: 0.4170 - val_recall: 0.4459 - val_precision: 0.4706 - val_accuracy: 0.4478 - lr: 0.0010
# Epoch 7/500
# 103/103 [==============================] - 83s 810ms/step - loss: 0.0725 - recall: 0.8341 - precision: 0.8890 - accuracy: 0.8639 - val_loss: 0.3773 - val_recall: 0.5737 - val_precision: 0.5931 - val_accuracy: 0.5835 - lr: 0.0010
# Epoch 8/500
# 103/103 [==============================] - 83s 805ms/step - loss: 0.0686 - recall: 0.8474 - precision: 0.8954 - accuracy: 0.8718 - val_loss: 0.6064 - val_recall: 0.1605 - val_precision: 0.1775 - val_accuracy: 0.1688 - lr: 0.0010
# Epoch 9/500
# 103/103 [==============================] - 83s 808ms/step - loss: 0.0623 - recall: 0.8657 - precision: 0.9083 - accuracy: 0.8870 - val_loss: 0.2798 - val_recall: 0.5378 - val_precision: 0.5694 - val_accuracy: 0.5470 - lr: 0.0010
# Epoch 10/500
# 103/103 [==============================] - 83s 804ms/step - loss: 0.0630 - recall: 0.8623 - precision: 0.9017 - accuracy: 0.8837 - val_loss: 0.4210 - val_recall: 0.3749 - val_precision: 0.3909 - val_accuracy: 0.3749 - lr: 0.0010
# Epoch 11/500
# 103/103 [==============================] - 87s 847ms/step - loss: 0.0561 - recall: 0.8784 - precision: 0.9116 - accuracy: 0.8955 - val_loss: 0.8650 - val_recall: 0.3761 - val_precision: 0.3908 - val_accuracy: 0.3844 - lr: 0.0010
# Epoch 12/500
# 103/103 [==============================] - 83s 806ms/step - loss: 0.0547 - recall: 0.8856 - precision: 0.9122 - accuracy: 0.8994 - val_loss: 0.3304 - val_recall: 0.5510 - val_precision: 0.5704 - val_accuracy: 0.5547 - lr: 0.0010
# Epoch 13/500
# 103/103 [==============================] - 83s 804ms/step - loss: 0.0491 - recall: 0.9000 - precision: 0.9243 - accuracy: 0.9120 - val_loss: 0.4252 - val_recall: 0.3629 - val_precision: 0.4068 - val_accuracy: 0.3743 - lr: 0.0010
# Epoch 14/500
# 103/103 [==============================] - 84s 811ms/step - loss: 0.0489 - recall: 0.9005 - precision: 0.9247 - accuracy: 0.9139 - val_loss: 0.2433 - val_recall: 0.6168 - val_precision: 0.6503 - val_accuracy: 0.6303 - lr: 0.0010
# Epoch 15/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0460 - recall: 0.9031 - precision: 0.9255 - accuracy: 0.9156 - val_loss: 1.1207 - val_recall: 0.1651 - val_precision: 0.1486 - val_accuracy: 0.1534 - lr: 0.0010
# Epoch 16/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0458 - recall: 0.9097 - precision: 0.9307 - accuracy: 0.9204 - val_loss: 0.3303 - val_recall: 0.5694 - val_precision: 0.5866 - val_accuracy: 0.5792 - lr: 0.0010
# Epoch 17/500
# 103/103 [==============================] - 83s 808ms/step - loss: 0.0377 - recall: 0.9259 - precision: 0.9403 - accuracy: 0.9347 - val_loss: 0.1415 - val_recall: 0.7479 - val_precision: 0.7641 - val_accuracy: 0.7550 - lr: 0.0010
# Epoch 18/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0369 - recall: 0.9248 - precision: 0.9408 - accuracy: 0.9321 - val_loss: 0.3436 - val_recall: 0.5489 - val_precision: 0.5818 - val_accuracy: 0.5645 - lr: 0.0010
# Epoch 19/500
# 103/103 [==============================] - 83s 804ms/step - loss: 0.0387 - recall: 0.9233 - precision: 0.9382 - accuracy: 0.9301 - val_loss: 0.1452 - val_recall: 0.7899 - val_precision: 0.7972 - val_accuracy: 0.7914 - lr: 0.0010
# Epoch 20/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0362 - recall: 0.9285 - precision: 0.9425 - accuracy: 0.9358 - val_loss: 0.2957 - val_recall: 0.6315 - val_precision: 0.6613 - val_accuracy: 0.6380 - lr: 0.0010
# Epoch 21/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0339 - recall: 0.9330 - precision: 0.9451 - accuracy: 0.9397 - val_loss: 0.4200 - val_recall: 0.5660 - val_precision: 0.5867 - val_accuracy: 0.5706 - lr: 0.0010
# Epoch 22/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0321 - recall: 0.9340 - precision: 0.9475 - accuracy: 0.9421 - val_loss: 0.4295 - val_recall: 0.5525 - val_precision: 0.5780 - val_accuracy: 0.5562 - lr: 0.0010
# Epoch 23/500
# 103/103 [==============================] - 83s 804ms/step - loss: 0.0319 - recall: 0.9379 - precision: 0.9498 - accuracy: 0.9435 - val_loss: 0.4656 - val_recall: 0.6061 - val_precision: 0.6231 - val_accuracy: 0.6129 - lr: 0.0010
# Epoch 24/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0332 - recall: 0.9356 - precision: 0.9463 - accuracy: 0.9408 - val_loss: 0.3717 - val_recall: 0.4582 - val_precision: 0.4913 - val_accuracy: 0.4738 - lr: 0.0010
# Epoch 25/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0292 - recall: 0.9438 - precision: 0.9515 - accuracy: 0.9489 - val_loss: 0.4394 - val_recall: 0.5054 - val_precision: 0.5184 - val_accuracy: 0.5060 - lr: 0.0010
# Epoch 26/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0338 - recall: 0.9337 - precision: 0.9451 - accuracy: 0.9402 - val_loss: 0.2723 - val_recall: 0.6190 - val_precision: 0.6467 - val_accuracy: 0.6260 - lr: 0.0010
# Epoch 27/500
# 103/103 [==============================] - 83s 804ms/step - loss: 0.0312 - recall: 0.9395 - precision: 0.9498 - accuracy: 0.9453 - val_loss: 0.4617 - val_recall: 0.4937 - val_precision: 0.5023 - val_accuracy: 0.4928 - lr: 0.0010
# Epoch 28/500
# 103/103 [==============================] - 83s 808ms/step - loss: 0.0184 - recall: 0.9667 - precision: 0.9708 - accuracy: 0.9690 - val_loss: 0.0677 - val_recall: 0.8720 - val_precision: 0.8773 - val_accuracy: 0.8729 - lr: 1.0000e-04
# Epoch 29/500
# 103/103 [==============================] - 83s 807ms/step - loss: 0.0141 - recall: 0.9729 - precision: 0.9766 - accuracy: 0.9753 - val_loss: 0.0197 - val_recall: 0.9645 - val_precision: 0.9615 - val_accuracy: 0.9632 - lr: 1.0000e-04
# Epoch 30/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0129 - recall: 0.9762 - precision: 0.9793 - accuracy: 0.9779 - val_loss: 0.0460 - val_recall: 0.9216 - val_precision: 0.9160 - val_accuracy: 0.9198 - lr: 1.0000e-04
# Epoch 31/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0120 - recall: 0.9778 - precision: 0.9807 - accuracy: 0.9801 - val_loss: 0.0261 - val_recall: 0.9534 - val_precision: 0.9468 - val_accuracy: 0.9507 - lr: 1.0000e-04
# Epoch 32/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0126 - recall: 0.9767 - precision: 0.9789 - accuracy: 0.9781 - val_loss: 0.0287 - val_recall: 0.9507 - val_precision: 0.9472 - val_accuracy: 0.9479 - lr: 1.0000e-04
# Epoch 33/500
# 103/103 [==============================] - 87s 847ms/step - loss: 0.0106 - recall: 0.9810 - precision: 0.9816 - accuracy: 0.9814 - val_loss: 0.0307 - val_recall: 0.9516 - val_precision: 0.9478 - val_accuracy: 0.9495 - lr: 1.0000e-04
# Epoch 34/500
# 103/103 [==============================] - 83s 809ms/step - loss: 0.0098 - recall: 0.9826 - precision: 0.9835 - accuracy: 0.9830 - val_loss: 0.0101 - val_recall: 0.9819 - val_precision: 0.9780 - val_accuracy: 0.9810 - lr: 1.0000e-04
# Epoch 35/500
# 103/103 [==============================] - 83s 804ms/step - loss: 0.0104 - recall: 0.9809 - precision: 0.9815 - accuracy: 0.9814 - val_loss: 0.0561 - val_recall: 0.9109 - val_precision: 0.9092 - val_accuracy: 0.9087 - lr: 1.0000e-04
# Epoch 36/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0099 - recall: 0.9818 - precision: 0.9836 - accuracy: 0.9827 - val_loss: 0.0302 - val_recall: 0.9504 - val_precision: 0.9501 - val_accuracy: 0.9510 - lr: 1.0000e-04
# Epoch 37/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0095 - recall: 0.9832 - precision: 0.9838 - accuracy: 0.9838 - val_loss: 0.0556 - val_recall: 0.9176 - val_precision: 0.9193 - val_accuracy: 0.9185 - lr: 1.0000e-04
# Epoch 38/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0097 - recall: 0.9826 - precision: 0.9842 - accuracy: 0.9833 - val_loss: 0.0683 - val_recall: 0.8894 - val_precision: 0.8977 - val_accuracy: 0.8946 - lr: 1.0000e-04
# Epoch 39/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0092 - recall: 0.9828 - precision: 0.9851 - accuracy: 0.9847 - val_loss: 0.0578 - val_recall: 0.9029 - val_precision: 0.8996 - val_accuracy: 0.9011 - lr: 1.0000e-04
# Epoch 40/500
# 103/103 [==============================] - 83s 809ms/step - loss: 0.0105 - recall: 0.9816 - precision: 0.9835 - accuracy: 0.9823 - val_loss: 0.0094 - val_recall: 0.9853 - val_precision: 0.9817 - val_accuracy: 0.9835 - lr: 1.0000e-04
# Epoch 41/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0083 - recall: 0.9839 - precision: 0.9852 - accuracy: 0.9849 - val_loss: 0.0898 - val_recall: 0.8723 - val_precision: 0.8856 - val_accuracy: 0.8784 - lr: 1.0000e-04
# Epoch 42/500
# 103/103 [==============================] - 83s 805ms/step - loss: 0.0078 - recall: 0.9858 - precision: 0.9856 - accuracy: 0.9859 - val_loss: 0.0097 - val_recall: 0.9822 - val_precision: 0.9786 - val_accuracy: 0.9795 - lr: 1.0000e-04
# Epoch 43/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0099 - recall: 0.9832 - precision: 0.9838 - accuracy: 0.9836 - val_loss: 0.0690 - val_recall: 0.8998 - val_precision: 0.9010 - val_accuracy: 0.9014 - lr: 1.0000e-04
# Epoch 44/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0081 - recall: 0.9858 - precision: 0.9865 - accuracy: 0.9864 - val_loss: 0.0550 - val_recall: 0.9216 - val_precision: 0.9199 - val_accuracy: 0.9204 - lr: 1.0000e-04
# Epoch 45/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0088 - recall: 0.9834 - precision: 0.9854 - accuracy: 0.9843 - val_loss: 0.0143 - val_recall: 0.9786 - val_precision: 0.9765 - val_accuracy: 0.9773 - lr: 1.0000e-04
# Epoch 46/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0074 - recall: 0.9872 - precision: 0.9890 - accuracy: 0.9878 - val_loss: 0.0214 - val_recall: 0.9617 - val_precision: 0.9617 - val_accuracy: 0.9626 - lr: 1.0000e-04
# Epoch 47/500
# 103/103 [==============================] - 83s 805ms/step - loss: 0.0075 - recall: 0.9863 - precision: 0.9865 - accuracy: 0.9862 - val_loss: 0.0753 - val_recall: 0.8953 - val_precision: 0.8955 - val_accuracy: 0.8931 - lr: 1.0000e-04
# Epoch 48/500
# 103/103 [==============================] - 83s 809ms/step - loss: 0.0078 - recall: 0.9860 - precision: 0.9871 - accuracy: 0.9869 - val_loss: 0.0076 - val_recall: 0.9871 - val_precision: 0.9856 - val_accuracy: 0.9859 - lr: 1.0000e-04
# Epoch 49/500
# 103/103 [==============================] - 83s 804ms/step - loss: 0.0070 - recall: 0.9874 - precision: 0.9878 - accuracy: 0.9874 - val_loss: 0.1496 - val_recall: 0.8138 - val_precision: 0.8160 - val_accuracy: 0.8132 - lr: 1.0000e-04
# Epoch 50/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0068 - recall: 0.9864 - precision: 0.9882 - accuracy: 0.9878 - val_loss: 0.0086 - val_recall: 0.9832 - val_precision: 0.9835 - val_accuracy: 0.9847 - lr: 1.0000e-04
# Epoch 51/500
# 103/103 [==============================] - 83s 805ms/step - loss: 0.0074 - recall: 0.9862 - precision: 0.9879 - accuracy: 0.9869 - val_loss: 0.0839 - val_recall: 0.8931 - val_precision: 0.8879 - val_accuracy: 0.8904 - lr: 1.0000e-04
# Epoch 52/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0059 - recall: 0.9889 - precision: 0.9903 - accuracy: 0.9897 - val_loss: 0.0178 - val_recall: 0.9724 - val_precision: 0.9689 - val_accuracy: 0.9709 - lr: 1.0000e-04
# Epoch 53/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0057 - recall: 0.9893 - precision: 0.9905 - accuracy: 0.9901 - val_loss: 0.0559 - val_recall: 0.9219 - val_precision: 0.9264 - val_accuracy: 0.9219 - lr: 1.0000e-04
# Epoch 54/500
# 103/103 [==============================] - 83s 805ms/step - loss: 0.0067 - recall: 0.9875 - precision: 0.9884 - accuracy: 0.9879 - val_loss: 0.0251 - val_recall: 0.9550 - val_precision: 0.9561 - val_accuracy: 0.9559 - lr: 1.0000e-04
# Epoch 55/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0072 - recall: 0.9874 - precision: 0.9875 - accuracy: 0.9882 - val_loss: 0.0144 - val_recall: 0.9761 - val_precision: 0.9740 - val_accuracy: 0.9752 - lr: 1.0000e-04
# Epoch 56/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0054 - recall: 0.9903 - precision: 0.9922 - accuracy: 0.9914 - val_loss: 0.0162 - val_recall: 0.9724 - val_precision: 0.9707 - val_accuracy: 0.9718 - lr: 1.0000e-04
# Epoch 57/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0071 - recall: 0.9880 - precision: 0.9887 - accuracy: 0.9888 - val_loss: 0.1099 - val_recall: 0.8315 - val_precision: 0.8385 - val_accuracy: 0.8334 - lr: 1.0000e-04
# Epoch 58/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0077 - recall: 0.9850 - precision: 0.9868 - accuracy: 0.9860 - val_loss: 0.0438 - val_recall: 0.9320 - val_precision: 0.9354 - val_accuracy: 0.9332 - lr: 1.0000e-04
# Epoch 59/500
# 103/103 [==============================] - 83s 804ms/step - loss: 0.0054 - recall: 0.9902 - precision: 0.9909 - accuracy: 0.9906 - val_loss: 0.0130 - val_recall: 0.9786 - val_precision: 0.9753 - val_accuracy: 0.9764 - lr: 1.0000e-05
# Epoch 60/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0051 - recall: 0.9907 - precision: 0.9910 - accuracy: 0.9911 - val_loss: 0.0170 - val_recall: 0.9730 - val_precision: 0.9695 - val_accuracy: 0.9721 - lr: 1.0000e-05
# Epoch 61/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0043 - recall: 0.9920 - precision: 0.9936 - accuracy: 0.9926 - val_loss: 0.0112 - val_recall: 0.9819 - val_precision: 0.9801 - val_accuracy: 0.9798 - lr: 1.0000e-05
# Epoch 62/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0049 - recall: 0.9911 - precision: 0.9923 - accuracy: 0.9919 - val_loss: 0.0101 - val_recall: 0.9822 - val_precision: 0.9819 - val_accuracy: 0.9816 - lr: 1.0000e-05
# Epoch 63/500
# 103/103 [==============================] - 83s 804ms/step - loss: 0.0041 - recall: 0.9927 - precision: 0.9932 - accuracy: 0.9934 - val_loss: 0.0190 - val_recall: 0.9697 - val_precision: 0.9667 - val_accuracy: 0.9681 - lr: 1.0000e-05
# Epoch 64/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0046 - recall: 0.9921 - precision: 0.9924 - accuracy: 0.9922 - val_loss: 0.0100 - val_recall: 0.9832 - val_precision: 0.9814 - val_accuracy: 0.9825 - lr: 1.0000e-05
# Epoch 65/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0046 - recall: 0.9918 - precision: 0.9919 - accuracy: 0.9921 - val_loss: 0.0114 - val_recall: 0.9807 - val_precision: 0.9789 - val_accuracy: 0.9795 - lr: 1.0000e-05
# Epoch 66/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0044 - recall: 0.9920 - precision: 0.9921 - accuracy: 0.9924 - val_loss: 0.0128 - val_recall: 0.9798 - val_precision: 0.9774 - val_accuracy: 0.9783 - lr: 1.0000e-05
# Epoch 67/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0043 - recall: 0.9927 - precision: 0.9937 - accuracy: 0.9934 - val_loss: 0.0117 - val_recall: 0.9795 - val_precision: 0.9789 - val_accuracy: 0.9795 - lr: 1.0000e-05
# Epoch 68/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0042 - recall: 0.9921 - precision: 0.9922 - accuracy: 0.9924 - val_loss: 0.0156 - val_recall: 0.9749 - val_precision: 0.9728 - val_accuracy: 0.9743 - lr: 1.0000e-05
# Epoch 69/500
# 103/103 [==============================] - 83s 802ms/step - loss: 0.0038 - recall: 0.9932 - precision: 0.9932 - accuracy: 0.9936 - val_loss: 0.0091 - val_recall: 0.9850 - val_precision: 0.9826 - val_accuracy: 0.9841 - lr: 1.0000e-05
# Epoch 70/500
# 103/103 [==============================] - 83s 804ms/step - loss: 0.0035 - recall: 0.9927 - precision: 0.9941 - accuracy: 0.9936 - val_loss: 0.0131 - val_recall: 0.9783 - val_precision: 0.9768 - val_accuracy: 0.9776 - lr: 1.0000e-05
# Epoch 71/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0038 - recall: 0.9927 - precision: 0.9936 - accuracy: 0.9931 - val_loss: 0.0389 - val_recall: 0.9513 - val_precision: 0.9478 - val_accuracy: 0.9498 - lr: 1.0000e-05
# Epoch 72/500
# 103/103 [==============================] - 83s 806ms/step - loss: 0.0039 - recall: 0.9934 - precision: 0.9932 - accuracy: 0.9937 - val_loss: 0.0149 - val_recall: 0.9779 - val_precision: 0.9747 - val_accuracy: 0.9761 - lr: 1.0000e-05
# Epoch 73/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0036 - recall: 0.9942 - precision: 0.9943 - accuracy: 0.9943 - val_loss: 0.0114 - val_recall: 0.9810 - val_precision: 0.9795 - val_accuracy: 0.9801 - lr: 1.0000e-06
# Epoch 74/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0035 - recall: 0.9930 - precision: 0.9937 - accuracy: 0.9940 - val_loss: 0.0106 - val_recall: 0.9822 - val_precision: 0.9807 - val_accuracy: 0.9819 - lr: 1.0000e-06
# Epoch 75/500
# 103/103 [==============================] - 83s 803ms/step - loss: 0.0041 - recall: 0.9928 - precision: 0.9928 - accuracy: 0.9930 - val_loss: 0.0106 - val_recall: 0.9825 - val_precision: 0.9804 - val_accuracy: 0.9810 - lr: 1.0000e-06
# Epoch 76/500
# 103/103 [==============================] - 83s 802ms/step - loss: 0.0039 - recall: 0.9933 - precision: 0.9930 - accuracy: 0.9936 - val_loss: 0.0107 - val_recall: 0.9825 - val_precision: 0.9804 - val_accuracy: 0.9810 - lr: 1.0000e-06
# Epoch 77/500
# 103/103 [==============================] - 83s 802ms/step - loss: 0.0035 - recall: 0.9937 - precision: 0.9943 - accuracy: 0.9941 - val_loss: 0.0106 - val_recall: 0.9828 - val_precision: 0.9801 - val_accuracy: 0.9810 - lr: 1.0000e-06
# Epoch 78/500
# 103/103 [==============================] - 83s 804ms/step - loss: 0.0035 - recall: 0.9935 - precision: 0.9934 - accuracy: 0.9938 - val_loss: 0.0111 - val_recall: 0.9813 - val_precision: 0.9801 - val_accuracy: 0.9804 - lr: 1.0000e-06

# %%
exp_conv.evaluate(test_x,test_y)
# Out:
# 57/57 [==============================] - 5s 87ms/step - loss: 0.0077 - recall: 0.9873 - precision: 0.9846 - accuracy: 0.9851
# [0.007699406240135431,
#  0.9873068332672119,
#  0.9845899939537048,
#  0.9850993156433105]

# %%
exp_conv.predict(test_x)
# Out:
# 57/57 [==============================] - 4s 55ms/step
# array([[8.8438755e-06, 9.9926219e-05, 7.3918600e-05, ..., 2.3498424e-07,
#         1.8716801e-05, 5.0687697e-04],
#        [2.3051702e-07, 1.4785482e-05, 2.2830102e-07, ..., 4.3891152e-08,
#         2.3158130e-07, 1.3284492e-06],
#        [9.6790666e-07, 1.2134294e-05, 2.8712810e-05, ..., 9.5473984e-09,
#         3.0891303e-07, 2.1822522e-04],
#        ...,
#        [1.5912270e-09, 1.3103914e-09, 3.9855473e-05, ..., 8.4197662e-09,
#         5.4467802e-11, 9.9997115e-01],
#        [1.7509758e-11, 2.6243677e-11, 9.4560949e-07, ..., 2.4010008e-10,
#         3.3349443e-12, 9.9999666e-01],
#        [3.2836255e-14, 5.8390209e-14, 1.0714019e-07, ..., 1.5741507e-12,
#         2.7268813e-15, 9.9999988e-01]], dtype=float32)

# %%
figure, axes = plt.subplots(nrows=1, ncols=3, figsize=[9, 3], dpi=100)
axes = axes.ravel()
epochs = list(range(len(history.history['loss'])))

sns.lineplot(x=epochs, y=history.history['loss'], ax=axes[0],label='loss')
sns.lineplot(x=epochs, y=history.history['val_loss'], ax=axes[0],label='val loss')
sns.lineplot(x=epochs, y=history.history['precision'], ax=axes[1],label='precision')
sns.lineplot(x=epochs, y=history.history['val_precision'], ax=axes[1],label='val precision')
sns.lineplot(x=epochs, y=history.history['recall'], color='#025918', ax=axes[1],label='recall')
sns.lineplot(x=epochs, y=history.history['val_recall'], color='#D9B504',ax=axes[1],label='val recall')
sns.lineplot(x=epochs, y=history.history['accuracy'], ax=axes[2],label='accuracy')
sns.lineplot(x=epochs, y=history.history['val_accuracy'], ax=axes[2],label='val accuracy')
axes[0].set_xlabel('epoch')
axes[0].set_ylabel('loss')
axes[1].set_xlabel('epoch')
axes[1].set_ylabel('precision and recall')
axes[2].set_xlabel('epoch')
axes[2].set_ylabel('accuracy')
plt.savefig('VGGNet_base_conv_train_history_with_cassava.png')
plt.show()

# %%
figure, axes = plt.subplots(nrows=1, ncols=2, figsize=[6, 3], dpi=100)
axes = axes.ravel()

sns.lineplot(x=epochs, y=history.history['lr'], ax=axes[0],label='learning rate')
sns.lineplot(x=history.history['lr'], y=history.history['val_accuracy'], ax=axes[1],label='accuracy & lr')
axes[0].set_xlabel('epoch')
axes[0].set_ylabel('learning rate')
axes[1].set_xlabel('learning rate')
axes[1].set_ylabel('accuracy')

plt.savefig('VGGNet_base_conv_lr_history_4.png')
plt.show()

# %%
# Plot confusion matrix
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=[15, 10], dpi=100)
axes = axes.ravel()

preds = np.where(exp_conv.predict(test_x) < 0.65, 0, 1)
confusion = multilabel_confusion_matrix(test_y, preds)

for i, (label, matrix) in enumerate(zip(mlb.classes_, confusion)):
    labels = [f'not_{label}', label]
    xlabels = [f'p_not_{label}', f'p_{label}']
    sns.heatmap(matrix, annot=True, square=True, fmt='d', cbar=False, cmap='Blues',
                xticklabels=xlabels, yticklabels=labels, linecolor='black', linewidth=1,
                ax=axes[i])
    axes[i].set_title(labels[0])

plt.savefig('VGGNet_base_conv_4_cm.png')
plt.show()
# Out:
# 57/57 [==============================] - 3s 56ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-a06ce916fd5a> in <module>
#      11     sns.heatmap(matrix, annot=True, square=True, fmt='d', cbar=False, cmap='Blues',
#      12                 xticklabels=xlabels, yticklabels=labels, linecolor='black', linewidth=1,
# ---> 13                 ax=axes[i])
#      14     axes[i].set_title(labels[0])
#      15
#
# IndexError: index 6 is out of bounds for axis 0 with size 6

# %%
exp_conv.save('/content/drive/MyDrive/Tomato(0.0076).hdf5')-

# %%
mlb.classes_

# %%
exp_conv.predict(test_x[200:201])

# %%
preds[i][:].argmax()

# %%
fig, axes = plt.subplots(nrows=5, ncols=2,figsize = (8, 24))
preds = exp_conv.predict(test_x[200:210])
axes = axes.ravel()

for i in range(len(preds)):
    p = zip(list(mlb.classes_), list(preds[i]))
    p = sorted(list(p), key = lambda z: z[1], reverse = True)[:2]
    axes[i].imshow(test_x[200+i])
    axes[i].set_title(f'{p[0][0]}: {round(p[0][1] * 100, 2)}% \n {p[1][0]}: {round(p[1][1] * 100, 2)}%')

# %%
pd.to_pickle(pd.DataFrame(history.history), 'VGGNet_base_conv_lr_history.pkl')

# %%
model_path = '/content/drive/MyDrive/Apple(0.0096).hdf5'
file_path = '/content/abr1.jpeg'

# %%
model = load_model(model_path)

# %%
img = load_img(file_path,target_size=(56,56))

# %%
img

# %%
img_arr = img_to_array(img)

# %%
img_arr.shape
# Out:
# (56, 56, 3)

# %%
res_img_arr = np.reshape(img_arr,(1,56,56,3))
res_img_arr

# %%
pred = model.predict(generator.flow(res_img_arr))
pred
# Out:
# 1/1 [==============================] - 0s 434ms/step
# array([[0.35702926, 0.02839291, 0.65592957, 0.0305153 ]], dtype=float32)

# %%
pred[0][:].argmax()
# Out:
# 2

# %%
mlb.classes_
# Out:
# array(['Apple scab', 'Black rot', 'Cedar apple rust', 'healthy'],
#       dtype=object)

# %%
model_path = '/content/drive/MyDrive/Apple(0.0096).hdf5'
file_path = '/content/as3.jpg'

# %%
def test(file_path):
  model = load_model(model_path)
  img = load_img(file_path,target_size=(56,56))
  img_arr = img_to_array(img)
  res_img_arr = np.reshape(img_arr,(1,56,56,3))
  pred = model.predict(generator.flow(res_img_arr))
  return mlb.classes_[:][pred[0][:].argmax()], f'{round(pred[0][pred[0][:].argmax()]*100,2)}%'

# %%
test(file_path)
# Out:
# 1/1 [==============================] - 0s 434ms/step
# ('Cedar apple rust', '74.23%')

# %%
pred.tolist()[0][1]
# Out:
# 0.028392909094691277

# %%
for i,ii in enumerate(mlb.classes_):
  print(f'{ii} : {round(pred.tolist()[0][i],2)}%')
# Out:
# Apple scab : 0.36%
# Black rot : 0.03%
# Cedar apple rust : 0.66%
# healthy : 0.03%
