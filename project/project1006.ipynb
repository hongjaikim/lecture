# %%
import os
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import cv2 as cv

import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import multilabel_confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization, concatenate
from tensorflow.keras.activations import relu, sigmoid
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.utils import plot_model, save_img
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

# %%
base_dir = '../input'

# %%
plant_village_dir = '/content/drive/MyDrive/plantvillage dataset'

# %%
fnames = []

for dir in os.listdir(os.path.join(plant_village_dir, 'color')):
    columns = dir.split('___')
    columns.append(dir)
    fnames.append(columns)

# %%
fnames = pd.DataFrame(fnames, columns=['Tree type', 'Disease', 'Folder'])
fnames
# Out:
#                   Tree type                               Disease  \
# 0                     Apple                            Apple_scab
# 1                     Apple                             Black_rot
# 2                     Apple                      Cedar_apple_rust
# 3                     Apple                               healthy
# 4                 Blueberry                               healthy
# 5   Cherry_(including_sour)                        Powdery_mildew
# 6   Cherry_(including_sour)                               healthy
# 7              Corn_(maize)   Cercospora_leaf_spot Gray_leaf_spot
# 8              Corn_(maize)                          Common_rust_
# 9              Corn_(maize)                  Northern_Leaf_Blight
# 10             Corn_(maize)                               healthy
# 11                    Grape                             Black_rot
# 12                    Grape                  Esca_(Black_Measles)
# 13                    Grape    Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                    Grape                               healthy
# 15                   Orange       Haunglongbing_(Citrus_greening)
# 16                    Peach                        Bacterial_spot
# 17                    Peach                               healthy
# 18             Pepper,_bell                        Bacterial_spot
# 19             Pepper,_bell                               healthy
# 20                   Potato                          Early_blight
# 21                   Potato                           Late_blight
# 22                   Potato                               healthy
# 23                Raspberry                               healthy
# 24                  Soybean                               healthy
# 25                   Squash                        Powdery_mildew
# 26               Strawberry                           Leaf_scorch
# 27               Strawberry                               healthy
# 28                   Tomato                        Bacterial_spot
# 29                   Tomato                          Early_blight
# 30                   Tomato                           Late_blight
# 31                   Tomato                             Leaf_Mold
# 32                   Tomato                    Septoria_leaf_spot
# 33                   Tomato  Spider_mites Two-spotted_spider_mite
# 34                   Tomato                           Target_Spot
# 35                   Tomato         Tomato_Yellow_Leaf_Curl_Virus
# 36                   Tomato                   Tomato_mosaic_virus
# 37                   Tomato                               healthy
#
#                                                Folder
# 0                                  Apple___Apple_scab
# 1                                   Apple___Black_rot
# 2                            Apple___Cedar_apple_rust
# 3                                     Apple___healthy
# 4                                 Blueberry___healthy
# 5            Cherry_(including_sour)___Powdery_mildew
# 6                   Cherry_(including_sour)___healthy
# 7   Corn_(maize)___Cercospora_leaf_spot Gray_leaf_...
# 8                         Corn_(maize)___Common_rust_
# 9                 Corn_(maize)___Northern_Leaf_Blight
# 10                             Corn_(maize)___healthy
# 11                                  Grape___Black_rot
# 12                       Grape___Esca_(Black_Measles)
# 13         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                                    Grape___healthy
# 15           Orange___Haunglongbing_(Citrus_greening)
# 16                             Peach___Bacterial_spot
# 17                                    Peach___healthy
# 18                      Pepper,_bell___Bacterial_spot
# 19                             Pepper,_bell___healthy
# 20                              Potato___Early_blight
# 21                               Potato___Late_blight
# 22                                   Potato___healthy
# 23                                Raspberry___healthy
# 24                                  Soybean___healthy
# 25                            Squash___Powdery_mildew
# 26                           Strawberry___Leaf_scorch
# 27                               Strawberry___healthy
# 28                            Tomato___Bacterial_spot
# 29                              Tomato___Early_blight
# 30                               Tomato___Late_blight
# 31                                 Tomato___Leaf_Mold
# 32                        Tomato___Septoria_leaf_spot
# 33      Tomato___Spider_mites Two-spotted_spider_mite
# 34                               Tomato___Target_Spot
# 35             Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 36                       Tomato___Tomato_mosaic_virus
# 37                                   Tomato___healthy

# %%
fnames.drop([4,23,24],axis=0,inplace=True)
fnames
# Out:
#                   Tree type                               Disease  \
# 0                     Apple                            Apple_scab
# 1                     Apple                             Black_rot
# 2                     Apple                      Cedar_apple_rust
# 3                     Apple                               healthy
# 5   Cherry_(including_sour)                        Powdery_mildew
# 6   Cherry_(including_sour)                               healthy
# 7              Corn_(maize)   Cercospora_leaf_spot Gray_leaf_spot
# 8              Corn_(maize)                          Common_rust_
# 9              Corn_(maize)                  Northern_Leaf_Blight
# 10             Corn_(maize)                               healthy
# 11                    Grape                             Black_rot
# 12                    Grape                  Esca_(Black_Measles)
# 13                    Grape    Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                    Grape                               healthy
# 15                   Orange       Haunglongbing_(Citrus_greening)
# 16                    Peach                        Bacterial_spot
# 17                    Peach                               healthy
# 18             Pepper,_bell                        Bacterial_spot
# 19             Pepper,_bell                               healthy
# 20                   Potato                          Early_blight
# 21                   Potato                           Late_blight
# 22                   Potato                               healthy
# 25                   Squash                        Powdery_mildew
# 26               Strawberry                           Leaf_scorch
# 27               Strawberry                               healthy
# 28                   Tomato                        Bacterial_spot
# 29                   Tomato                          Early_blight
# 30                   Tomato                           Late_blight
# 31                   Tomato                             Leaf_Mold
# 32                   Tomato                    Septoria_leaf_spot
# 33                   Tomato  Spider_mites Two-spotted_spider_mite
# 34                   Tomato                           Target_Spot
# 35                   Tomato         Tomato_Yellow_Leaf_Curl_Virus
# 36                   Tomato                   Tomato_mosaic_virus
# 37                   Tomato                               healthy
#
#                                                Folder
# 0                                  Apple___Apple_scab
# 1                                   Apple___Black_rot
# 2                            Apple___Cedar_apple_rust
# 3                                     Apple___healthy
# 5            Cherry_(including_sour)___Powdery_mildew
# 6                   Cherry_(including_sour)___healthy
# 7   Corn_(maize)___Cercospora_leaf_spot Gray_leaf_...
# 8                         Corn_(maize)___Common_rust_
# 9                 Corn_(maize)___Northern_Leaf_Blight
# 10                             Corn_(maize)___healthy
# 11                                  Grape___Black_rot
# 12                       Grape___Esca_(Black_Measles)
# 13         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                                    Grape___healthy
# 15           Orange___Haunglongbing_(Citrus_greening)
# 16                             Peach___Bacterial_spot
# 17                                    Peach___healthy
# 18                      Pepper,_bell___Bacterial_spot
# 19                             Pepper,_bell___healthy
# 20                              Potato___Early_blight
# 21                               Potato___Late_blight
# 22                                   Potato___healthy
# 25                            Squash___Powdery_mildew
# 26                           Strawberry___Leaf_scorch
# 27                               Strawberry___healthy
# 28                            Tomato___Bacterial_spot
# 29                              Tomato___Early_blight
# 30                               Tomato___Late_blight
# 31                                 Tomato___Leaf_Mold
# 32                        Tomato___Septoria_leaf_spot
# 33      Tomato___Spider_mites Two-spotted_spider_mite
# 34                               Tomato___Target_Spot
# 35             Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 36                       Tomato___Tomato_mosaic_virus
# 37                                   Tomato___healthy

# %%
fnames['Disease'] = fnames['Disease'].str.replace('_', ' ')
fnames['Disease'] = fnames['Disease'].str.lstrip()
fnames['Tree type'] = fnames['Tree type'].str.replace('_', ' ')
fnames['Tree type'] = fnames['Tree type'].str.lstrip()
fnames
# Out:
#                   Tree type                               Disease  \
# 0                     Apple                            Apple scab
# 1                     Apple                             Black rot
# 2                     Apple                      Cedar apple rust
# 3                     Apple                               healthy
# 5   Cherry (including sour)                        Powdery mildew
# 6   Cherry (including sour)                               healthy
# 7              Corn (maize)   Cercospora leaf spot Gray leaf spot
# 8              Corn (maize)                          Common rust
# 9              Corn (maize)                  Northern Leaf Blight
# 10             Corn (maize)                               healthy
# 11                    Grape                             Black rot
# 12                    Grape                  Esca (Black Measles)
# 13                    Grape    Leaf blight (Isariopsis Leaf Spot)
# 14                    Grape                               healthy
# 15                   Orange       Haunglongbing (Citrus greening)
# 16                    Peach                        Bacterial spot
# 17                    Peach                               healthy
# 18             Pepper, bell                        Bacterial spot
# 19             Pepper, bell                               healthy
# 20                   Potato                          Early blight
# 21                   Potato                           Late blight
# 22                   Potato                               healthy
# 25                   Squash                        Powdery mildew
# 26               Strawberry                           Leaf scorch
# 27               Strawberry                               healthy
# 28                   Tomato                        Bacterial spot
# 29                   Tomato                          Early blight
# 30                   Tomato                           Late blight
# 31                   Tomato                             Leaf Mold
# 32                   Tomato                    Septoria leaf spot
# 33                   Tomato  Spider mites Two-spotted spider mite
# 34                   Tomato                           Target Spot
# 35                   Tomato         Tomato Yellow Leaf Curl Virus
# 36                   Tomato                   Tomato mosaic virus
# 37                   Tomato                               healthy
#
#                                                Folder
# 0                                  Apple___Apple_scab
# 1                                   Apple___Black_rot
# 2                            Apple___Cedar_apple_rust
# 3                                     Apple___healthy
# 5            Cherry_(including_sour)___Powdery_mildew
# 6                   Cherry_(including_sour)___healthy
# 7   Corn_(maize)___Cercospora_leaf_spot Gray_leaf_...
# 8                         Corn_(maize)___Common_rust_
# 9                 Corn_(maize)___Northern_Leaf_Blight
# 10                             Corn_(maize)___healthy
# 11                                  Grape___Black_rot
# 12                       Grape___Esca_(Black_Measles)
# 13         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                                    Grape___healthy
# 15           Orange___Haunglongbing_(Citrus_greening)
# 16                             Peach___Bacterial_spot
# 17                                    Peach___healthy
# 18                      Pepper,_bell___Bacterial_spot
# 19                             Pepper,_bell___healthy
# 20                              Potato___Early_blight
# 21                               Potato___Late_blight
# 22                                   Potato___healthy
# 25                            Squash___Powdery_mildew
# 26                           Strawberry___Leaf_scorch
# 27                               Strawberry___healthy
# 28                            Tomato___Bacterial_spot
# 29                              Tomato___Early_blight
# 30                               Tomato___Late_blight
# 31                                 Tomato___Leaf_Mold
# 32                        Tomato___Septoria_leaf_spot
# 33      Tomato___Spider_mites Two-spotted_spider_mite
# 34                               Tomato___Target_Spot
# 35             Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 36                       Tomato___Tomato_mosaic_virus
# 37                                   Tomato___healthy

# %%
os.mkdir('image data')

# %%
os.mkdir(os.path.join('image data', 'train'))
os.mkdir(os.path.join('image data', 'validation'))
os.mkdir(os.path.join('image data', 'test'))

# %%
train_path = os.path.join('image data/train')
val_path = os.path.join('image data/validation')
test_path = os.path.join('image data/test')

# %%
for tree in fnames['Tree type'].unique().tolist():
    # create directory for tree
    path_1 = os.path.join(train_path, tree)
    path_2 = os.path.join(test_path, tree)
    path_3 = os.path.join(val_path, tree)

    os.mkdir(path_1)
    os.mkdir(path_2)
    os.mkdir(path_3)

    for disease, folder in fnames[fnames['Tree type'] == tree][['Disease', 'Folder']].values.tolist():
        # create directory to each disease
        sub_path_1 = os.path.join(path_1, disease.strip())
        sub_path_2 = os.path.join(path_2, disease.strip())
        sub_path_3 = os.path.join(path_3, disease.strip())

        os.mkdir(sub_path_1)
        os.mkdir(sub_path_2)
        os.mkdir(sub_path_3)

        # read data from source folder
        src = os.path.join(plant_village_dir, 'color', folder)
        image_count = len(os.listdir(src))
        test_img_count = image_count // 10
        val_img_count = (image_count - test_img_count) // 5
        train_img_count = image_count - (test_img_count + val_img_count)
        counts = [train_img_count, test_img_count, val_img_count]
        splits = [sub_path_1, sub_path_2, sub_path_3]

        for i in range(3):
            images = os.listdir(src)
            for j in images[:counts[i]]:
                shutil.copyfile(src=os.path.join(src, j),
                                dst=os.path.join(splits[i], j))

# %%
X = []
y = []
val_x = []
val_y = []
test_x = []
test_y = []
tree_types = os.listdir('image data/train')

for tree in tree_types:
    tree_path = os.path.join('image data/train', tree)
    tree_disease_types = os.listdir(tree_path)

    for disease in tree_disease_types:
        img_name = os.listdir(os.path.join(tree_path, disease))

        for img in img_name:
            image_path = os.path.join(tree_path, disease, img)
            image = img_to_array(load_img(image_path, target_size=(56,56)))
            X.append(image)
            y.append([tree, disease])
            
for tree in tree_types:
    tree_path = os.path.join('image data/validation', tree)
    tree_disease_types = os.listdir(tree_path)

    for disease in tree_disease_types:
        img_name = os.listdir(os.path.join(tree_path, disease))

        for img in img_name:
            image_path = os.path.join(tree_path, disease, img)
            image = img_to_array(load_img(image_path, target_size=(56,56)))
            val_x.append(image)
            val_y.append([tree, disease])
            
for tree in tree_types:
    tree_path = os.path.join('image data/test', tree)
    tree_disease_types = os.listdir(tree_path)

    for disease in tree_disease_types:
        img_name = os.listdir(os.path.join(tree_path, disease))

        for img in img_name:
            image_path = os.path.join(tree_path, disease, img)
            image = img_to_array(load_img(image_path, target_size=(56,56)))
            test_x.append(image)
            test_y.append([tree, disease])

# %%
mlb = MultiLabelBinarizer()

X = np.array(X)
val_x = np.array(val_x)
y = mlb.fit_transform(y)
val_y = mlb.transform(val_y)
test_y = mlb.transform(test_y)
test_x = np.array(test_x)/255
val_x = val_x/255
X.shape, y.shape
# Out:
# ((34112, 56, 56, 3), (34112, 32))

# %%
generator = ImageDataGenerator(rescale=1. / 255,
                               rotation_range=15,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               horizontal_flip=True,
                               vertical_flip=True
                                    )
generator.fit(X)

# %%
check_pointer = ModelCheckpoint(filepath='exp_conv_20.hdf5',
                                save_best_only=True)

early_stop = EarlyStopping(monitor='val_loss',
                           patience=40,
                           min_delta=0,
                           restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.1,
                              patience=20,
                             cooldown=15)

# %%
def inception_module(x, filter_1x1, filter_3x3_reduce, filter_3x3, filter_5x5_reduce, filter_5x5, filters_pool_proj,
                     name=None):
    # reduction layer
    conv_3x3_reducer = Conv2D(filters=filter_3x3_reduce, kernel_size=(1, 1), activation=relu, padding='same')(x)
    conv_5x5_reducer = Conv2D(filters=filter_5x5_reduce, kernel_size=(1, 1), activation=relu, padding='same')(x)
    pool_3x3 = MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same')(x)

    # extraction layer
    conv_3x3 = Conv2D(filters=filter_3x3, kernel_size=(3, 3), activation=relu, padding='same')(conv_3x3_reducer)
    conv_5x5 = Conv2D(filters=filter_5x5, kernel_size=(5, 5), activation=relu, padding='same')(conv_5x5_reducer)
    conv_1x1_proj = Conv2D(filters=filters_pool_proj, kernel_size=(1, 1), activation=relu, padding='same')(pool_3x3)

    # projection layer
    proj = Conv2D(filters=filter_1x1, kernel_size=(1, 1), activation=relu, padding='same')(x)

    # output
    x = concatenate([proj, conv_1x1_proj, conv_3x3, conv_5x5], axis=3, name=name)

    return x

# %%
exp_input = Input(shape=(56,56,3))

# conv_7x7
x = Conv2D(filters=64, kernel_size=(7,7), padding='same', activation=relu)(exp_input)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(3,3), strides=(1,1))(x)

# conv_5x5
x = Conv2D(filters=192, kernel_size=(5,5), padding='same', activation=relu)(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(3,3), strides=(1,1))(x)

# inception block 1
x = inception_module(x,
                     filter_1x1=64,
                     filter_5x5_reduce=96,
                     filter_3x3=128,
                     filter_3x3_reduce=16,
                     filter_5x5=32,
                     filters_pool_proj=32,
                     name='inception_1a')
x = inception_module(x,
                     filter_1x1=96,
                     filter_5x5_reduce=128,
                     filter_3x3=160,
                     filter_3x3_reduce=32,
                     filter_5x5=48,
                     filters_pool_proj=64,
                     name='inception_1b')

# pooling
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

# inception block 2
x = inception_module(x,
                     filter_1x1=128,
                     filter_5x5_reduce=96,
                     filter_3x3=128,
                     filter_3x3_reduce=48,
                     filter_5x5=32,
                     filters_pool_proj=32,
                     name='inception_2a')
x = inception_module(x,
                     filter_1x1=160,
                     filter_5x5_reduce=112,
                     filter_3x3=160,
                     filter_3x3_reduce=32,
                     filter_5x5=64,
                     filters_pool_proj=64,
                     name='inception_2b')
x = inception_module(x,
                     filter_1x1=192,
                     filter_5x5_reduce=128,
                     filter_3x3=128,
                     filter_3x3_reduce=48,
                     filter_5x5=64,
                     filters_pool_proj=64,
                     name='inception_2c')
x = inception_module(x,
                     filter_1x1=256,
                     filter_5x5_reduce=160,
                     filter_3x3=160,
                     filter_3x3_reduce=32,
                     filter_5x5=96,
                     filters_pool_proj=96,
                     name='inception_2d')

# pooling
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

# conv 3x3
x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

# flatten
x = Flatten()(x)

# output layer
x = Dense(units=1024, activation=relu)(x)
x = Dropout(0.5)(x)
x = Dense(units=1024, activation=relu)(x)
x = Dropout(0.5)(x)
exp_output = Dense(units=32, activation=sigmoid)(x)     # units 개수?????

exp_conv = Model(exp_input, exp_output)
exp_conv.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 56, 56, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 56, 56, 64)   9472        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 56, 56, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  max_pooling2d (MaxPooling2D)   (None, 54, 54, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 54, 54, 192)  307392      ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 54, 54, 192)  768        ['conv2d_1[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 52, 52, 192)  0          ['batch_normalization_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 52, 52, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 52, 52, 16)   3088        ['max_pooling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 52, 52, 96)   18528       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 52, 52, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 52, 52, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 52, 52, 128)  18560       ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 52, 52, 32)   76832       ['conv2d_3[0][0]']
#
#  inception_1a (Concatenate)     (None, 52, 52, 256)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 256)  0          ['inception_1a[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 52, 52, 32)   8224        ['inception_1a[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 52, 52, 128)  32896       ['inception_1a[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 52, 52, 96)   24672       ['inception_1a[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 52, 52, 64)   16448       ['max_pooling2d_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 52, 52, 160)  46240       ['conv2d_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 52, 52, 48)   153648      ['conv2d_9[0][0]']
#
#  inception_1b (Concatenate)     (None, 52, 52, 368)  0           ['conv2d_13[0][0]',
#                                                                   'conv2d_12[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 52, 52, 368)  1472       ['inception_1b[0][0]']
#  rmalization)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 26, 26, 368)  0          ['batch_normalization_2[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 26, 26, 368)  0          ['max_pooling2d_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 26, 26, 48)   17712       ['max_pooling2d_4[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 26, 26, 96)   35424       ['max_pooling2d_4[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 26, 26, 128)  47232       ['max_pooling2d_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 26, 26, 32)   11808       ['max_pooling2d_5[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 26, 26, 128)  55424       ['conv2d_14[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 26, 26, 32)   76832       ['conv2d_15[0][0]']
#
#  inception_2a (Concatenate)     (None, 26, 26, 320)  0           ['conv2d_19[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_16[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 26, 26, 320)  0          ['inception_2a[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 26, 26, 32)   10272       ['inception_2a[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 26, 26, 112)  35952       ['inception_2a[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 26, 26, 160)  51360       ['inception_2a[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 26, 26, 64)   20544       ['max_pooling2d_6[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 26, 26, 160)  46240       ['conv2d_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 26, 26, 64)   179264      ['conv2d_21[0][0]']
#
#  inception_2b (Concatenate)     (None, 26, 26, 448)  0           ['conv2d_25[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_22[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 26, 26, 448)  0          ['inception_2b[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 26, 26, 48)   21552       ['inception_2b[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 26, 26, 128)  57472       ['inception_2b[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 26, 26, 192)  86208       ['inception_2b[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 26, 26, 64)   28736       ['max_pooling2d_7[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 26, 26, 128)  55424       ['conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 26, 26, 64)   204864      ['conv2d_27[0][0]']
#
#  inception_2c (Concatenate)     (None, 26, 26, 448)  0           ['conv2d_31[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_28[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 26, 26, 448)  0          ['inception_2c[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 26, 26, 32)   14368       ['inception_2c[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 26, 26, 160)  71840       ['inception_2c[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 26, 26, 256)  114944      ['inception_2c[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 26, 26, 96)   43104       ['max_pooling2d_8[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 26, 26, 160)  46240       ['conv2d_32[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 26, 26, 96)   384096      ['conv2d_33[0][0]']
#
#  inception_2d (Concatenate)     (None, 26, 26, 608)  0           ['conv2d_37[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_34[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 26, 26, 608)  2432       ['inception_2d[0][0]']
#  rmalization)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 13, 13, 608)  0          ['batch_normalization_3[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 13, 13, 256)  1401088     ['max_pooling2d_9[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 13, 13, 256)  590080      ['conv2d_38[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 13, 13, 256)  1024       ['conv2d_39[0][0]']
#  rmalization)
#
#  max_pooling2d_10 (MaxPooling2D  (None, 7, 7, 256)   0           ['batch_normalization_4[0][0]']
#  )
#
#  conv2d_40 (Conv2D)             (None, 7, 7, 256)    590080      ['max_pooling2d_10[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 7, 7, 256)    590080      ['conv2d_40[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_41[0][0]']
#  rmalization)
#
#  max_pooling2d_11 (MaxPooling2D  (None, 4, 4, 256)   0           ['batch_normalization_5[0][0]']
#  )
#
#  conv2d_42 (Conv2D)             (None, 4, 4, 256)    590080      ['max_pooling2d_11[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 4, 4, 256)    590080      ['conv2d_42[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 4, 4, 256)   1024        ['conv2d_43[0][0]']
#  rmalization)
#
#  max_pooling2d_12 (MaxPooling2D  (None, 2, 2, 256)   0           ['batch_normalization_6[0][0]']
#  )
#
#  flatten (Flatten)              (None, 1024)         0           ['max_pooling2d_12[0][0]']
#
#  dense (Dense)                  (None, 1024)         1049600     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1024)         1049600     ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           32800       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 8,942,928
# Trainable params: 8,938,928
# Non-trainable params: 4,000
# __________________________________________________________________________________________________

# %%
# plot_model(exp_conv,
#            to_file='baseline_conv_15_exp(VGGNet with INCEPTION).png',
#            show_shapes=True,
#            show_dtype=True,
#            show_layer_names=True)

# %%
exp_conv.compile(optimizer=Adam(),
                   loss=binary_crossentropy,
                   metrics=[Recall(), Precision(), 'accuracy'])

history = exp_conv.fit(generator.flow(X,y, batch_size=128), 
                        epochs=500, 
                        validation_data=(val_x,val_y),
                        callbacks=[early_stop, check_pointer, reduce_lr])
# Out:
# Epoch 1/500
# 267/267 [==============================] - 268s 907ms/step - loss: 0.1532 - recall: 0.3690 - precision: 0.6710 - accuracy: 0.2533 - val_loss: 0.3017 - val_recall: 0.2708 - val_precision: 0.3282 - val_accuracy: 0.1491 - lr: 0.0010
# Epoch 2/500
# 267/267 [==============================] - 237s 887ms/step - loss: 0.0934 - recall: 0.6077 - precision: 0.8122 - accuracy: 0.3387 - val_loss: 0.1673 - val_recall: 0.4937 - val_precision: 0.6031 - val_accuracy: 0.1849 - lr: 0.0010
# Epoch 3/500
# 267/267 [==============================] - 237s 886ms/step - loss: 0.0695 - recall: 0.7188 - precision: 0.8543 - accuracy: 0.3856 - val_loss: 0.1475 - val_recall: 0.6024 - val_precision: 0.6513 - val_accuracy: 0.2643 - lr: 0.0010
# Epoch 4/500
# 267/267 [==============================] - 240s 900ms/step - loss: 0.0539 - recall: 0.7926 - precision: 0.8816 - accuracy: 0.4075 - val_loss: 0.1612 - val_recall: 0.5264 - val_precision: 0.6325 - val_accuracy: 0.3720 - lr: 0.0010
# Epoch 5/500
# 267/267 [==============================] - 236s 884ms/step - loss: 0.0428 - recall: 0.8444 - precision: 0.9024 - accuracy: 0.4238 - val_loss: 0.0780 - val_recall: 0.7977 - val_precision: 0.8139 - val_accuracy: 0.4452 - lr: 0.0010
# Epoch 6/500
# 267/267 [==============================] - 235s 879ms/step - loss: 0.0332 - recall: 0.8859 - precision: 0.9240 - accuracy: 0.4303 - val_loss: 0.1626 - val_recall: 0.5876 - val_precision: 0.6434 - val_accuracy: 0.3154 - lr: 0.0010
# Epoch 7/500
# 267/267 [==============================] - 235s 880ms/step - loss: 0.0294 - recall: 0.9032 - precision: 0.9313 - accuracy: 0.4380 - val_loss: 0.1885 - val_recall: 0.5196 - val_precision: 0.5643 - val_accuracy: 0.2333 - lr: 0.0010
# Epoch 8/500
# 267/267 [==============================] - 235s 879ms/step - loss: 0.0282 - recall: 0.9099 - precision: 0.9347 - accuracy: 0.4539 - val_loss: 0.0911 - val_recall: 0.7582 - val_precision: 0.7916 - val_accuracy: 0.4796 - lr: 0.0010
# Epoch 9/500
# 267/267 [==============================] - 235s 881ms/step - loss: 0.0239 - recall: 0.9232 - precision: 0.9451 - accuracy: 0.4466 - val_loss: 0.1363 - val_recall: 0.6462 - val_precision: 0.6880 - val_accuracy: 0.3455 - lr: 0.0010
# Epoch 10/500
# 267/267 [==============================] - 234s 875ms/step - loss: 0.0209 - recall: 0.9345 - precision: 0.9515 - accuracy: 0.4644 - val_loss: 0.2798 - val_recall: 0.4934 - val_precision: 0.5186 - val_accuracy: 0.2651 - lr: 0.0010
# Epoch 11/500
# 267/267 [==============================] - 235s 879ms/step - loss: 0.0180 - recall: 0.9452 - precision: 0.9587 - accuracy: 0.4529 - val_loss: 0.1285 - val_recall: 0.6989 - val_precision: 0.7246 - val_accuracy: 0.3790 - lr: 0.0010
# Epoch 12/500
# 267/267 [==============================] - 233s 872ms/step - loss: 0.0189 - recall: 0.9421 - precision: 0.9564 - accuracy: 0.4519 - val_loss: 0.1046 - val_recall: 0.6943 - val_precision: 0.7313 - val_accuracy: 0.3844 - lr: 0.0010
# Epoch 13/500
# 267/267 [==============================] - 234s 876ms/step - loss: 0.0179 - recall: 0.9455 - precision: 0.9592 - accuracy: 0.4688 - val_loss: 0.0435 - val_recall: 0.8856 - val_precision: 0.8919 - val_accuracy: 0.4394 - lr: 0.0010
# Epoch 14/500
# 267/267 [==============================] - 234s 877ms/step - loss: 0.0167 - recall: 0.9502 - precision: 0.9613 - accuracy: 0.4766 - val_loss: 0.0699 - val_recall: 0.7990 - val_precision: 0.8198 - val_accuracy: 0.4679 - lr: 0.0010
# Epoch 15/500
# 267/267 [==============================] - 233s 873ms/step - loss: 0.0151 - recall: 0.9554 - precision: 0.9654 - accuracy: 0.4859 - val_loss: 0.2768 - val_recall: 0.4263 - val_precision: 0.4534 - val_accuracy: 0.2179 - lr: 0.0010
# Epoch 16/500
# 267/267 [==============================] - 233s 872ms/step - loss: 0.0149 - recall: 0.9567 - precision: 0.9668 - accuracy: 0.4682 - val_loss: 0.1323 - val_recall: 0.6823 - val_precision: 0.7007 - val_accuracy: 0.3579 - lr: 0.0010
# Epoch 17/500
# 267/267 [==============================] - 233s 874ms/step - loss: 0.0127 - recall: 0.9632 - precision: 0.9705 - accuracy: 0.4943 - val_loss: 0.0874 - val_recall: 0.8110 - val_precision: 0.8224 - val_accuracy: 0.4015 - lr: 0.0010
# Epoch 18/500
# 267/267 [==============================] - 233s 873ms/step - loss: 0.0135 - recall: 0.9631 - precision: 0.9708 - accuracy: 0.5002 - val_loss: 0.2129 - val_recall: 0.5652 - val_precision: 0.5767 - val_accuracy: 0.3324 - lr: 0.0010
# Epoch 19/500
# 267/267 [==============================] - 237s 889ms/step - loss: 0.0140 - recall: 0.9593 - precision: 0.9682 - accuracy: 0.5010 - val_loss: 0.0509 - val_recall: 0.8927 - val_precision: 0.9004 - val_accuracy: 0.4710 - lr: 0.0010
# Epoch 20/500
# 267/267 [==============================] - 233s 871ms/step - loss: 0.0129 - recall: 0.9633 - precision: 0.9715 - accuracy: 0.4862 - val_loss: 0.2217 - val_recall: 0.4020 - val_precision: 0.4460 - val_accuracy: 0.2473 - lr: 0.0010
# Epoch 21/500
# 267/267 [==============================] - 234s 875ms/step - loss: 0.0121 - recall: 0.9648 - precision: 0.9720 - accuracy: 0.4930 - val_loss: 0.0539 - val_recall: 0.8597 - val_precision: 0.8803 - val_accuracy: 0.4655 - lr: 0.0010
# Epoch 22/500
# 267/267 [==============================] - 233s 871ms/step - loss: 0.0103 - recall: 0.9709 - precision: 0.9770 - accuracy: 0.5070 - val_loss: 0.3056 - val_recall: 0.5518 - val_precision: 0.5702 - val_accuracy: 0.3686 - lr: 0.0010
# Epoch 23/500
# 267/267 [==============================] - 232s 870ms/step - loss: 0.0099 - recall: 0.9726 - precision: 0.9780 - accuracy: 0.5029 - val_loss: 0.1260 - val_recall: 0.7482 - val_precision: 0.7637 - val_accuracy: 0.3957 - lr: 0.0010
# Epoch 24/500
# 267/267 [==============================] - 232s 868ms/step - loss: 0.0091 - recall: 0.9748 - precision: 0.9793 - accuracy: 0.5262 - val_loss: 0.1565 - val_recall: 0.7566 - val_precision: 0.7693 - val_accuracy: 0.4257 - lr: 0.0010
# Epoch 25/500
# 267/267 [==============================] - 233s 871ms/step - loss: 0.0105 - recall: 0.9699 - precision: 0.9760 - accuracy: 0.5358 - val_loss: 0.0417 - val_recall: 0.8882 - val_precision: 0.9004 - val_accuracy: 0.5532 - lr: 0.0010
# Epoch 26/500
# 267/267 [==============================] - 232s 868ms/step - loss: 0.0093 - recall: 0.9739 - precision: 0.9786 - accuracy: 0.5149 - val_loss: 0.1732 - val_recall: 0.6857 - val_precision: 0.7059 - val_accuracy: 0.4596 - lr: 0.0010
# Epoch 27/500
# 267/267 [==============================] - 232s 869ms/step - loss: 0.0086 - recall: 0.9760 - precision: 0.9803 - accuracy: 0.5242 - val_loss: 0.0656 - val_recall: 0.8443 - val_precision: 0.8585 - val_accuracy: 0.4575 - lr: 0.0010
# Epoch 28/500
# 267/267 [==============================] - 232s 868ms/step - loss: 0.0085 - recall: 0.9765 - precision: 0.9812 - accuracy: 0.5332 - val_loss: 0.0543 - val_recall: 0.8791 - val_precision: 0.8873 - val_accuracy: 0.4355 - lr: 0.0010
# Epoch 29/500
# 267/267 [==============================] - 232s 870ms/step - loss: 0.0084 - recall: 0.9767 - precision: 0.9810 - accuracy: 0.5349 - val_loss: 0.0383 - val_recall: 0.9057 - val_precision: 0.9116 - val_accuracy: 0.5303 - lr: 0.0010
# Epoch 30/500
# 267/267 [==============================] - 232s 868ms/step - loss: 0.0091 - recall: 0.9757 - precision: 0.9797 - accuracy: 0.5266 - val_loss: 0.0118 - val_recall: 0.9667 - val_precision: 0.9684 - val_accuracy: 0.5186 - lr: 0.0010
# Epoch 31/500
# 267/267 [==============================] - 231s 865ms/step - loss: 0.0107 - recall: 0.9726 - precision: 0.9777 - accuracy: 0.5377 - val_loss: 2.5864 - val_recall: 0.2288 - val_precision: 0.2288 - val_accuracy: 0.1004 - lr: 0.0010
# Epoch 32/500
# 267/267 [==============================] - 231s 865ms/step - loss: 0.0108 - recall: 0.9704 - precision: 0.9769 - accuracy: 0.5356 - val_loss: 0.0734 - val_recall: 0.9005 - val_precision: 0.9047 - val_accuracy: 0.4734 - lr: 0.0010
# Epoch 33/500
# 267/267 [==============================] - 231s 864ms/step - loss: 0.0067 - recall: 0.9825 - precision: 0.9854 - accuracy: 0.5472 - val_loss: 0.1261 - val_recall: 0.7301 - val_precision: 0.7564 - val_accuracy: 0.3792 - lr: 0.0010
# Epoch 34/500
# 267/267 [==============================] - 231s 864ms/step - loss: 0.0070 - recall: 0.9802 - precision: 0.9834 - accuracy: 0.5570 - val_loss: 0.0348 - val_recall: 0.9143 - val_precision: 0.9199 - val_accuracy: 0.5596 - lr: 0.0010
# Epoch 35/500
# 267/267 [==============================] - 230s 862ms/step - loss: 0.0109 - recall: 0.9706 - precision: 0.9771 - accuracy: 0.5321 - val_loss: 0.1480 - val_recall: 0.6882 - val_precision: 0.7147 - val_accuracy: 0.3768 - lr: 0.0010
# Epoch 36/500
# 267/267 [==============================] - 231s 864ms/step - loss: 0.0068 - recall: 0.9806 - precision: 0.9836 - accuracy: 0.5414 - val_loss: 0.0150 - val_recall: 0.9646 - val_precision: 0.9649 - val_accuracy: 0.5404 - lr: 0.0010
# Epoch 37/500
# 267/267 [==============================] - 230s 862ms/step - loss: 0.0066 - recall: 0.9825 - precision: 0.9854 - accuracy: 0.5663 - val_loss: 0.0474 - val_recall: 0.9187 - val_precision: 0.9186 - val_accuracy: 0.4702 - lr: 0.0010
# Epoch 38/500
# 267/267 [==============================] - 231s 863ms/step - loss: 0.0062 - recall: 0.9828 - precision: 0.9859 - accuracy: 0.5620 - val_loss: 0.1194 - val_recall: 0.7594 - val_precision: 0.7745 - val_accuracy: 0.4485 - lr: 0.0010
# Epoch 39/500
# 267/267 [==============================] - 231s 863ms/step - loss: 0.0057 - recall: 0.9847 - precision: 0.9868 - accuracy: 0.5602 - val_loss: 0.1218 - val_recall: 0.7586 - val_precision: 0.7758 - val_accuracy: 0.4286 - lr: 0.0010
# Epoch 40/500
# 267/267 [==============================] - 230s 861ms/step - loss: 0.0063 - recall: 0.9821 - precision: 0.9856 - accuracy: 0.5730 - val_loss: 0.0606 - val_recall: 0.8504 - val_precision: 0.8660 - val_accuracy: 0.5044 - lr: 0.0010
# Epoch 41/500
# 267/267 [==============================] - 230s 862ms/step - loss: 0.0059 - recall: 0.9839 - precision: 0.9871 - accuracy: 0.5834 - val_loss: 0.0465 - val_recall: 0.8972 - val_precision: 0.9044 - val_accuracy: 0.4677 - lr: 0.0010
# Epoch 42/500
# 267/267 [==============================] - 230s 861ms/step - loss: 0.0099 - recall: 0.9727 - precision: 0.9794 - accuracy: 0.5867 - val_loss: 0.0303 - val_recall: 0.9227 - val_precision: 0.9270 - val_accuracy: 0.5388 - lr: 0.0010
# Epoch 43/500
# 267/267 [==============================] - 230s 861ms/step - loss: 0.0060 - recall: 0.9835 - precision: 0.9861 - accuracy: 0.5741 - val_loss: 0.1379 - val_recall: 0.7368 - val_precision: 0.7549 - val_accuracy: 0.4301 - lr: 0.0010
# Epoch 44/500
# 267/267 [==============================] - 236s 883ms/step - loss: 0.0054 - recall: 0.9857 - precision: 0.9878 - accuracy: 0.5734 - val_loss: 0.0118 - val_recall: 0.9706 - val_precision: 0.9699 - val_accuracy: 0.5768 - lr: 0.0010
# Epoch 45/500
# 267/267 [==============================] - 230s 862ms/step - loss: 0.0056 - recall: 0.9849 - precision: 0.9878 - accuracy: 0.5940 - val_loss: 0.0995 - val_recall: 0.7741 - val_precision: 0.7939 - val_accuracy: 0.5124 - lr: 0.0010
# Epoch 46/500
# 267/267 [==============================] - 230s 861ms/step - loss: 0.0051 - recall: 0.9854 - precision: 0.9882 - accuracy: 0.5913 - val_loss: 0.0392 - val_recall: 0.9015 - val_precision: 0.9153 - val_accuracy: 0.5252 - lr: 0.0010
# Epoch 47/500
# 267/267 [==============================] - 230s 861ms/step - loss: 0.0051 - recall: 0.9860 - precision: 0.9879 - accuracy: 0.5796 - val_loss: 0.1551 - val_recall: 0.6809 - val_precision: 0.7126 - val_accuracy: 0.4111 - lr: 0.0010
# Epoch 48/500
# 267/267 [==============================] - 230s 861ms/step - loss: 0.0050 - recall: 0.9863 - precision: 0.9886 - accuracy: 0.5772 - val_loss: 0.0203 - val_recall: 0.9511 - val_precision: 0.9529 - val_accuracy: 0.5975 - lr: 0.0010
# Epoch 49/500
# 267/267 [==============================] - 230s 861ms/step - loss: 0.0051 - recall: 0.9865 - precision: 0.9887 - accuracy: 0.5929 - val_loss: 0.0199 - val_recall: 0.9486 - val_precision: 0.9516 - val_accuracy: 0.5464 - lr: 0.0010
# Epoch 50/500
# 267/267 [==============================] - 229s 858ms/step - loss: 0.0050 - recall: 0.9871 - precision: 0.9893 - accuracy: 0.6030 - val_loss: 0.0398 - val_recall: 0.9128 - val_precision: 0.9183 - val_accuracy: 0.5740 - lr: 0.0010
# Epoch 51/500
# 267/267 [==============================] - 230s 862ms/step - loss: 0.0024 - recall: 0.9936 - precision: 0.9945 - accuracy: 0.5959 - val_loss: 0.0025 - val_recall: 0.9945 - val_precision: 0.9935 - val_accuracy: 0.6371 - lr: 1.0000e-04
# Epoch 52/500
# 267/267 [==============================] - 230s 863ms/step - loss: 0.0017 - recall: 0.9956 - precision: 0.9961 - accuracy: 0.6135 - val_loss: 0.0016 - val_recall: 0.9961 - val_precision: 0.9955 - val_accuracy: 0.6366 - lr: 1.0000e-04
# Epoch 53/500
# 267/267 [==============================] - 230s 860ms/step - loss: 0.0013 - recall: 0.9962 - precision: 0.9965 - accuracy: 0.6235 - val_loss: 0.0017 - val_recall: 0.9959 - val_precision: 0.9945 - val_accuracy: 0.6538 - lr: 1.0000e-04
# Epoch 54/500
# 267/267 [==============================] - 228s 853ms/step - loss: 0.0012 - recall: 0.9967 - precision: 0.9969 - accuracy: 0.6350 - val_loss: 0.0014 - val_recall: 0.9967 - val_precision: 0.9956 - val_accuracy: 0.6544 - lr: 1.0000e-04
# Epoch 55/500
# 267/267 [==============================] - 229s 859ms/step - loss: 0.0011 - recall: 0.9969 - precision: 0.9972 - accuracy: 0.6435 - val_loss: 0.0033 - val_recall: 0.9934 - val_precision: 0.9913 - val_accuracy: 0.6609 - lr: 1.0000e-04
# Epoch 56/500
# 267/267 [==============================] - 230s 863ms/step - loss: 0.0011 - recall: 0.9970 - precision: 0.9973 - accuracy: 0.6501 - val_loss: 9.6023e-04 - val_recall: 0.9974 - val_precision: 0.9968 - val_accuracy: 0.6957 - lr: 1.0000e-04
# Epoch 57/500
# 267/267 [==============================] - 227s 850ms/step - loss: 0.0010 - recall: 0.9971 - precision: 0.9973 - accuracy: 0.6624 - val_loss: 0.0040 - val_recall: 0.9924 - val_precision: 0.9912 - val_accuracy: 0.6937 - lr: 1.0000e-04
# Epoch 58/500
# 267/267 [==============================] - 227s 850ms/step - loss: 9.4704e-04 - recall: 0.9972 - precision: 0.9975 - accuracy: 0.6701 - val_loss: 0.0042 - val_recall: 0.9901 - val_precision: 0.9887 - val_accuracy: 0.6571 - lr: 1.0000e-04
# Epoch 59/500
# 267/267 [==============================] - 228s 854ms/step - loss: 8.5123e-04 - recall: 0.9975 - precision: 0.9976 - accuracy: 0.6728 - val_loss: 0.0020 - val_recall: 0.9955 - val_precision: 0.9946 - val_accuracy: 0.6892 - lr: 1.0000e-04
# Epoch 60/500
# 267/267 [==============================] - 229s 858ms/step - loss: 8.1328e-04 - recall: 0.9976 - precision: 0.9978 - accuracy: 0.6803 - val_loss: 0.0022 - val_recall: 0.9950 - val_precision: 0.9940 - val_accuracy: 0.6989 - lr: 1.0000e-04
# Epoch 61/500
# 267/267 [==============================] - 228s 856ms/step - loss: 9.2535e-04 - recall: 0.9974 - precision: 0.9976 - accuracy: 0.6816 - val_loss: 0.0207 - val_recall: 0.9652 - val_precision: 0.9632 - val_accuracy: 0.6337 - lr: 1.0000e-04
# Epoch 62/500
# 267/267 [==============================] - 229s 859ms/step - loss: 7.2213e-04 - recall: 0.9981 - precision: 0.9981 - accuracy: 0.6868 - val_loss: 5.6991e-04 - val_recall: 0.9986 - val_precision: 0.9981 - val_accuracy: 0.7465 - lr: 1.0000e-04
# Epoch 63/500
# 267/267 [==============================] - 226s 847ms/step - loss: 7.9913e-04 - recall: 0.9976 - precision: 0.9977 - accuracy: 0.7062 - val_loss: 0.0024 - val_recall: 0.9944 - val_precision: 0.9937 - val_accuracy: 0.7049 - lr: 1.0000e-04
# Epoch 64/500
# 267/267 [==============================] - 223s 835ms/step - loss: 7.9236e-04 - recall: 0.9977 - precision: 0.9979 - accuracy: 0.7070 - val_loss: 6.5914e-04 - val_recall: 0.9985 - val_precision: 0.9981 - val_accuracy: 0.7392 - lr: 1.0000e-04
# Epoch 65/500
# 267/267 [==============================] - 229s 856ms/step - loss: 9.1107e-04 - recall: 0.9979 - precision: 0.9979 - accuracy: 0.7025 - val_loss: 0.0028 - val_recall: 0.9938 - val_precision: 0.9926 - val_accuracy: 0.7234 - lr: 1.0000e-04
# Epoch 66/500
# 267/267 [==============================] - 229s 858ms/step - loss: 8.1567e-04 - recall: 0.9978 - precision: 0.9979 - accuracy: 0.7054 - val_loss: 0.0026 - val_recall: 0.9935 - val_precision: 0.9930 - val_accuracy: 0.6946 - lr: 1.0000e-04
# Epoch 67/500
# 267/267 [==============================] - 230s 860ms/step - loss: 6.1302e-04 - recall: 0.9981 - precision: 0.9984 - accuracy: 0.7173 - val_loss: 0.0039 - val_recall: 0.9917 - val_precision: 0.9911 - val_accuracy: 0.7438 - lr: 1.0000e-04
# Epoch 68/500
# 267/267 [==============================] - 229s 859ms/step - loss: 7.0845e-04 - recall: 0.9982 - precision: 0.9982 - accuracy: 0.7256 - val_loss: 0.0018 - val_recall: 0.9961 - val_precision: 0.9951 - val_accuracy: 0.7346 - lr: 1.0000e-04
# Epoch 69/500
# 267/267 [==============================] - 230s 859ms/step - loss: 7.5944e-04 - recall: 0.9980 - precision: 0.9983 - accuracy: 0.7270 - val_loss: 0.0384 - val_recall: 0.9467 - val_precision: 0.9455 - val_accuracy: 0.6316 - lr: 1.0000e-04
# Epoch 70/500
# 267/267 [==============================] - 230s 862ms/step - loss: 6.5292e-04 - recall: 0.9982 - precision: 0.9982 - accuracy: 0.7261 - val_loss: 0.0037 - val_recall: 0.9925 - val_precision: 0.9915 - val_accuracy: 0.7527 - lr: 1.0000e-04
# Epoch 71/500
# 267/267 [==============================] - 230s 860ms/step - loss: 7.1222e-04 - recall: 0.9979 - precision: 0.9980 - accuracy: 0.7387 - val_loss: 4.9001e-04 - val_recall: 0.9988 - val_precision: 0.9985 - val_accuracy: 0.7666 - lr: 1.0000e-04
# Epoch 72/500
# 267/267 [==============================] - 230s 860ms/step - loss: 5.9297e-04 - recall: 0.9983 - precision: 0.9984 - accuracy: 0.7450 - val_loss: 0.0026 - val_recall: 0.9938 - val_precision: 0.9931 - val_accuracy: 0.7415 - lr: 1.0000e-04
# Epoch 73/500
# 267/267 [==============================] - 230s 861ms/step - loss: 6.6789e-04 - recall: 0.9982 - precision: 0.9985 - accuracy: 0.7450 - val_loss: 0.0010 - val_recall: 0.9972 - val_precision: 0.9969 - val_accuracy: 0.7728 - lr: 1.0000e-04
# Epoch 74/500
# 267/267 [==============================] - 230s 859ms/step - loss: 6.6788e-04 - recall: 0.9980 - precision: 0.9981 - accuracy: 0.7519 - val_loss: 0.0055 - val_recall: 0.9882 - val_precision: 0.9867 - val_accuracy: 0.7318 - lr: 1.0000e-04
# Epoch 75/500
# 267/267 [==============================] - 229s 859ms/step - loss: 7.3907e-04 - recall: 0.9980 - precision: 0.9981 - accuracy: 0.7395 - val_loss: 5.9517e-04 - val_recall: 0.9985 - val_precision: 0.9985 - val_accuracy: 0.7832 - lr: 1.0000e-04
# Epoch 76/500
# 267/267 [==============================] - 230s 860ms/step - loss: 7.2599e-04 - recall: 0.9981 - precision: 0.9982 - accuracy: 0.7343 - val_loss: 0.0081 - val_recall: 0.9867 - val_precision: 0.9852 - val_accuracy: 0.7439 - lr: 1.0000e-04
# Epoch 77/500
# 267/267 [==============================] - 229s 858ms/step - loss: 5.1730e-04 - recall: 0.9986 - precision: 0.9987 - accuracy: 0.7486 - val_loss: 7.5993e-04 - val_recall: 0.9980 - val_precision: 0.9976 - val_accuracy: 0.7724 - lr: 1.0000e-04
# Epoch 78/500
# 267/267 [==============================] - 230s 861ms/step - loss: 4.7415e-04 - recall: 0.9986 - precision: 0.9987 - accuracy: 0.7561 - val_loss: 3.2374e-04 - val_recall: 0.9993 - val_precision: 0.9988 - val_accuracy: 0.7942 - lr: 1.0000e-04
# Epoch 79/500
# 267/267 [==============================] - 230s 860ms/step - loss: 5.5165e-04 - recall: 0.9984 - precision: 0.9985 - accuracy: 0.7585 - val_loss: 0.0015 - val_recall: 0.9966 - val_precision: 0.9959 - val_accuracy: 0.7781 - lr: 1.0000e-04
# Epoch 80/500
# 267/267 [==============================] - 230s 861ms/step - loss: 5.1260e-04 - recall: 0.9987 - precision: 0.9987 - accuracy: 0.7552 - val_loss: 9.7050e-04 - val_recall: 0.9976 - val_precision: 0.9969 - val_accuracy: 0.7638 - lr: 1.0000e-04
# Epoch 81/500
# 267/267 [==============================] - 230s 861ms/step - loss: 4.9136e-04 - recall: 0.9987 - precision: 0.9987 - accuracy: 0.7587 - val_loss: 5.6550e-04 - val_recall: 0.9986 - val_precision: 0.9982 - val_accuracy: 0.7957 - lr: 1.0000e-04
# Epoch 82/500
# 267/267 [==============================] - 230s 861ms/step - loss: 5.4073e-04 - recall: 0.9986 - precision: 0.9988 - accuracy: 0.7595 - val_loss: 6.1571e-04 - val_recall: 0.9984 - val_precision: 0.9979 - val_accuracy: 0.7882 - lr: 1.0000e-04
# Epoch 83/500
# 267/267 [==============================] - 230s 859ms/step - loss: 5.1582e-04 - recall: 0.9985 - precision: 0.9987 - accuracy: 0.7689 - val_loss: 0.0018 - val_recall: 0.9964 - val_precision: 0.9956 - val_accuracy: 0.7782 - lr: 1.0000e-04
# Epoch 84/500
# 267/267 [==============================] - 229s 858ms/step - loss: 5.2554e-04 - recall: 0.9985 - precision: 0.9986 - accuracy: 0.7787 - val_loss: 0.0022 - val_recall: 0.9952 - val_precision: 0.9942 - val_accuracy: 0.7802 - lr: 1.0000e-04
# Epoch 85/500
# 267/267 [==============================] - 230s 859ms/step - loss: 4.2924e-04 - recall: 0.9989 - precision: 0.9988 - accuracy: 0.7755 - val_loss: 0.0020 - val_recall: 0.9967 - val_precision: 0.9951 - val_accuracy: 0.7799 - lr: 1.0000e-04
# Epoch 86/500
# 267/267 [==============================] - 230s 860ms/step - loss: 4.9934e-04 - recall: 0.9986 - precision: 0.9987 - accuracy: 0.7783 - val_loss: 9.3080e-04 - val_recall: 0.9977 - val_precision: 0.9974 - val_accuracy: 0.8191 - lr: 1.0000e-04
# Epoch 87/500
# 267/267 [==============================] - 229s 857ms/step - loss: 5.6415e-04 - recall: 0.9985 - precision: 0.9986 - accuracy: 0.7784 - val_loss: 0.0071 - val_recall: 0.9861 - val_precision: 0.9840 - val_accuracy: 0.7593 - lr: 1.0000e-04
# Epoch 88/500
# 267/267 [==============================] - 230s 861ms/step - loss: 5.6484e-04 - recall: 0.9986 - precision: 0.9985 - accuracy: 0.7711 - val_loss: 0.0030 - val_recall: 0.9932 - val_precision: 0.9923 - val_accuracy: 0.7879 - lr: 1.0000e-04
# Epoch 89/500
# 102/267 [==========>...................] - ETA: 2:13 - loss: 4.0360e-04 - recall: 0.9990 - precision: 0.9989 - accuracy: 0.7848

# %%
exp_conv.evaluate(test_x,test_y)

# %%
figure, axes = plt.subplots(nrows=1, ncols=3, figsize=[18, 6], dpi=300)
axes = axes.ravel()
epochs = list(range(len(history.history['loss'])))

sns.lineplot(x=epochs, y=history.history['loss'], ax=axes[0],label='loss')
sns.lineplot(x=epochs, y=history.history['val_loss'], ax=axes[0],label='val loss')
sns.lineplot(x=epochs, y=history.history['precision'], ax=axes[1],label='precision')
sns.lineplot(x=epochs, y=history.history['val_precision'], ax=axes[1],label='val precision')
sns.lineplot(x=epochs, y=history.history['recall'], color='#025918', ax=axes[1],label='recall')
sns.lineplot(x=epochs, y=history.history['val_recall'], color='#D9B504',ax=axes[1],label='val recall')
sns.lineplot(x=epochs, y=history.history['accuracy'], ax=axes[2],label='accuracy')
sns.lineplot(x=epochs, y=history.history['val_accuracy'], ax=axes[2],label='val accuracy')
axes[0].set_xlabel('epoch')
axes[0].set_ylabel('loss')
axes[1].set_xlabel('epoch')
axes[1].set_ylabel('precision and recall')
axes[2].set_xlabel('epoch')
axes[2].set_ylabel('accuracy')
plt.savefig('VGGNet_base_conv_train_history_with_cassava.png')
plt.show()

# %%
figure, axes = plt.subplots(nrows=1, ncols=2, figsize=[12, 6], dpi=300)
axes = axes.ravel()

sns.lineplot(x=epochs, y=history.history['lr'], ax=axes[0],label='learning rate')
sns.lineplot(x=history.history['lr'], y=history.history['val_accuracy'], ax=axes[1],label='accuracy & lr')
axes[0].set_xlabel('epoch')
axes[0].set_ylabel('learning rate')
axes[1].set_xlabel('learning rate')
axes[1].set_ylabel('accuracy')

plt.savefig('VGGNet_base_conv_lr_history_4.png')
plt.show()

# %%
# Plot confusion matrix
fig, axes = plt.subplots(nrows=14, ncols=3, figsize=[24, 72], dpi=300)
axes = axes.ravel()

preds = np.where(exp_conv.predict(test_x) < 0.65, 0, 1)
confusion = multilabel_confusion_matrix(test_y, preds)

for i, (label, matrix) in enumerate(zip(mlb.classes_, confusion)):
    labels = [f'not_{label}', label]
    sns.heatmap(matrix, annot=True, square=True, fmt='d', cbar=False, cmap='Blues',
                xticklabels=labels, yticklabels=labels, linecolor='black', linewidth=1,
                ax=axes[i])
    axes[i].set_title(labels[0])

plt.savefig('VGGNet_base_conv_4_cm.png')
plt.show()

# %%
exp_conv.save('/content/drive/MyDrive/VGGNet_based_with_all_data_be_top.hdf5')

# %%
fig, axes = plt.subplots(nrows=5, ncols=2,figsize = (8, 24))
preds = exp_conv.predict(test_x[200:210])
axes = axes.ravel()

for i in range(len(preds)):
    p = zip(list(mlb.classes_), list(preds[i]))
    p = sorted(list(p), key = lambda z: z[1], reverse = True)[:2]
    axes[i].imshow(test_x[200+i])
    axes[i].set_title(f'{p[0][0]}: {round(p[0][1] * 100, 2)}% \n {p[1][0]}: {round(p[1][1] * 100, 2)}%')

# %%
pd.to_pickle(pd.DataFrame(history.history), 'VGGNet_base_conv_lr_history.pkl')
