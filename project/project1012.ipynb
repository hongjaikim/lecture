# %%
import os
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import cv2 as cv

import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import multilabel_confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization, concatenate
from tensorflow.keras.activations import relu, sigmoid
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.utils import plot_model, save_img
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from imblearn.over_sampling import ADASYN
from imblearn.under_sampling import OneSidedSelection

# %%
base_dir = '../input'

# %%
plant_village_dir = '/content/drive/MyDrive/plantvillage dataset'

# %%
fnames = []

for dir in os.listdir(os.path.join(plant_village_dir, 'color')):
    columns = dir.split('___')
    columns.append(dir)
    fnames.append(columns)

# %%
fnames = pd.DataFrame(fnames, columns=['Tree type', 'Disease', 'Folder'])
fnames
# Out:
#                   Tree type                               Disease  \
# 0                     Apple                            Apple_scab
# 1                     Apple                             Black_rot
# 2                     Apple                      Cedar_apple_rust
# 3                     Apple                               healthy
# 4                 Blueberry                               healthy
# 5   Cherry_(including_sour)                        Powdery_mildew
# 6   Cherry_(including_sour)                               healthy
# 7              Corn_(maize)   Cercospora_leaf_spot Gray_leaf_spot
# 8              Corn_(maize)                          Common_rust_
# 9              Corn_(maize)                  Northern_Leaf_Blight
# 10             Corn_(maize)                               healthy
# 11                    Grape                             Black_rot
# 12                    Grape                  Esca_(Black_Measles)
# 13                    Grape    Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                    Grape                               healthy
# 15                   Orange       Haunglongbing_(Citrus_greening)
# 16                    Peach                        Bacterial_spot
# 17                    Peach                               healthy
# 18             Pepper,_bell                        Bacterial_spot
# 19             Pepper,_bell                               healthy
# 20                   Potato                          Early_blight
# 21                   Potato                           Late_blight
# 22                   Potato                               healthy
# 23                Raspberry                               healthy
# 24                  Soybean                               healthy
# 25                   Squash                        Powdery_mildew
# 26               Strawberry                           Leaf_scorch
# 27               Strawberry                               healthy
# 28                   Tomato                        Bacterial_spot
# 29                   Tomato                          Early_blight
# 30                   Tomato                           Late_blight
# 31                   Tomato                             Leaf_Mold
# 32                   Tomato                    Septoria_leaf_spot
# 33                   Tomato  Spider_mites Two-spotted_spider_mite
# 34                   Tomato                           Target_Spot
# 35                   Tomato         Tomato_Yellow_Leaf_Curl_Virus
# 36                   Tomato                   Tomato_mosaic_virus
# 37                   Tomato                               healthy
#
#                                                Folder
# 0                                  Apple___Apple_scab
# 1                                   Apple___Black_rot
# 2                            Apple___Cedar_apple_rust
# 3                                     Apple___healthy
# 4                                 Blueberry___healthy
# 5            Cherry_(including_sour)___Powdery_mildew
# 6                   Cherry_(including_sour)___healthy
# 7   Corn_(maize)___Cercospora_leaf_spot Gray_leaf_...
# 8                         Corn_(maize)___Common_rust_
# 9                 Corn_(maize)___Northern_Leaf_Blight
# 10                             Corn_(maize)___healthy
# 11                                  Grape___Black_rot
# 12                       Grape___Esca_(Black_Measles)
# 13         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                                    Grape___healthy
# 15           Orange___Haunglongbing_(Citrus_greening)
# 16                             Peach___Bacterial_spot
# 17                                    Peach___healthy
# 18                      Pepper,_bell___Bacterial_spot
# 19                             Pepper,_bell___healthy
# 20                              Potato___Early_blight
# 21                               Potato___Late_blight
# 22                                   Potato___healthy
# 23                                Raspberry___healthy
# 24                                  Soybean___healthy
# 25                            Squash___Powdery_mildew
# 26                           Strawberry___Leaf_scorch
# 27                               Strawberry___healthy
# 28                            Tomato___Bacterial_spot
# 29                              Tomato___Early_blight
# 30                               Tomato___Late_blight
# 31                                 Tomato___Leaf_Mold
# 32                        Tomato___Septoria_leaf_spot
# 33      Tomato___Spider_mites Two-spotted_spider_mite
# 34                               Tomato___Target_Spot
# 35             Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 36                       Tomato___Tomato_mosaic_virus
# 37                                   Tomato___healthy

# %%
fnames.drop([4,23,24],axis=0,inplace=True)
fnames
# Out:
#                   Tree type                               Disease  \
# 0                     Apple                            Apple_scab
# 1                     Apple                             Black_rot
# 2                     Apple                      Cedar_apple_rust
# 3                     Apple                               healthy
# 5   Cherry_(including_sour)                        Powdery_mildew
# 6   Cherry_(including_sour)                               healthy
# 7              Corn_(maize)   Cercospora_leaf_spot Gray_leaf_spot
# 8              Corn_(maize)                          Common_rust_
# 9              Corn_(maize)                  Northern_Leaf_Blight
# 10             Corn_(maize)                               healthy
# 11                    Grape                             Black_rot
# 12                    Grape                  Esca_(Black_Measles)
# 13                    Grape    Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                    Grape                               healthy
# 15                   Orange       Haunglongbing_(Citrus_greening)
# 16                    Peach                        Bacterial_spot
# 17                    Peach                               healthy
# 18             Pepper,_bell                        Bacterial_spot
# 19             Pepper,_bell                               healthy
# 20                   Potato                          Early_blight
# 21                   Potato                           Late_blight
# 22                   Potato                               healthy
# 25                   Squash                        Powdery_mildew
# 26               Strawberry                           Leaf_scorch
# 27               Strawberry                               healthy
# 28                   Tomato                        Bacterial_spot
# 29                   Tomato                          Early_blight
# 30                   Tomato                           Late_blight
# 31                   Tomato                             Leaf_Mold
# 32                   Tomato                    Septoria_leaf_spot
# 33                   Tomato  Spider_mites Two-spotted_spider_mite
# 34                   Tomato                           Target_Spot
# 35                   Tomato         Tomato_Yellow_Leaf_Curl_Virus
# 36                   Tomato                   Tomato_mosaic_virus
# 37                   Tomato                               healthy
#
#                                                Folder
# 0                                  Apple___Apple_scab
# 1                                   Apple___Black_rot
# 2                            Apple___Cedar_apple_rust
# 3                                     Apple___healthy
# 5            Cherry_(including_sour)___Powdery_mildew
# 6                   Cherry_(including_sour)___healthy
# 7   Corn_(maize)___Cercospora_leaf_spot Gray_leaf_...
# 8                         Corn_(maize)___Common_rust_
# 9                 Corn_(maize)___Northern_Leaf_Blight
# 10                             Corn_(maize)___healthy
# 11                                  Grape___Black_rot
# 12                       Grape___Esca_(Black_Measles)
# 13         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                                    Grape___healthy
# 15           Orange___Haunglongbing_(Citrus_greening)
# 16                             Peach___Bacterial_spot
# 17                                    Peach___healthy
# 18                      Pepper,_bell___Bacterial_spot
# 19                             Pepper,_bell___healthy
# 20                              Potato___Early_blight
# 21                               Potato___Late_blight
# 22                                   Potato___healthy
# 25                            Squash___Powdery_mildew
# 26                           Strawberry___Leaf_scorch
# 27                               Strawberry___healthy
# 28                            Tomato___Bacterial_spot
# 29                              Tomato___Early_blight
# 30                               Tomato___Late_blight
# 31                                 Tomato___Leaf_Mold
# 32                        Tomato___Septoria_leaf_spot
# 33      Tomato___Spider_mites Two-spotted_spider_mite
# 34                               Tomato___Target_Spot
# 35             Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 36                       Tomato___Tomato_mosaic_virus
# 37                                   Tomato___healthy

# %%
fnames['Disease'] = fnames['Disease'].str.replace('_', ' ')
fnames['Disease'] = fnames['Disease'].str.lstrip()
fnames['Tree type'] = fnames['Tree type'].str.replace('_', ' ')
fnames['Tree type'] = fnames['Tree type'].str.lstrip()
fnames
# Out:
#                   Tree type                               Disease  \
# 0                     Apple                            Apple scab
# 1                     Apple                             Black rot
# 2                     Apple                      Cedar apple rust
# 3                     Apple                               healthy
# 5   Cherry (including sour)                        Powdery mildew
# 6   Cherry (including sour)                               healthy
# 7              Corn (maize)   Cercospora leaf spot Gray leaf spot
# 8              Corn (maize)                          Common rust
# 9              Corn (maize)                  Northern Leaf Blight
# 10             Corn (maize)                               healthy
# 11                    Grape                             Black rot
# 12                    Grape                  Esca (Black Measles)
# 13                    Grape    Leaf blight (Isariopsis Leaf Spot)
# 14                    Grape                               healthy
# 15                   Orange       Haunglongbing (Citrus greening)
# 16                    Peach                        Bacterial spot
# 17                    Peach                               healthy
# 18             Pepper, bell                        Bacterial spot
# 19             Pepper, bell                               healthy
# 20                   Potato                          Early blight
# 21                   Potato                           Late blight
# 22                   Potato                               healthy
# 25                   Squash                        Powdery mildew
# 26               Strawberry                           Leaf scorch
# 27               Strawberry                               healthy
# 28                   Tomato                        Bacterial spot
# 29                   Tomato                          Early blight
# 30                   Tomato                           Late blight
# 31                   Tomato                             Leaf Mold
# 32                   Tomato                    Septoria leaf spot
# 33                   Tomato  Spider mites Two-spotted spider mite
# 34                   Tomato                           Target Spot
# 35                   Tomato         Tomato Yellow Leaf Curl Virus
# 36                   Tomato                   Tomato mosaic virus
# 37                   Tomato                               healthy
#
#                                                Folder
# 0                                  Apple___Apple_scab
# 1                                   Apple___Black_rot
# 2                            Apple___Cedar_apple_rust
# 3                                     Apple___healthy
# 5            Cherry_(including_sour)___Powdery_mildew
# 6                   Cherry_(including_sour)___healthy
# 7   Corn_(maize)___Cercospora_leaf_spot Gray_leaf_...
# 8                         Corn_(maize)___Common_rust_
# 9                 Corn_(maize)___Northern_Leaf_Blight
# 10                             Corn_(maize)___healthy
# 11                                  Grape___Black_rot
# 12                       Grape___Esca_(Black_Measles)
# 13         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# 14                                    Grape___healthy
# 15           Orange___Haunglongbing_(Citrus_greening)
# 16                             Peach___Bacterial_spot
# 17                                    Peach___healthy
# 18                      Pepper,_bell___Bacterial_spot
# 19                             Pepper,_bell___healthy
# 20                              Potato___Early_blight
# 21                               Potato___Late_blight
# 22                                   Potato___healthy
# 25                            Squash___Powdery_mildew
# 26                           Strawberry___Leaf_scorch
# 27                               Strawberry___healthy
# 28                            Tomato___Bacterial_spot
# 29                              Tomato___Early_blight
# 30                               Tomato___Late_blight
# 31                                 Tomato___Leaf_Mold
# 32                        Tomato___Septoria_leaf_spot
# 33      Tomato___Spider_mites Two-spotted_spider_mite
# 34                               Tomato___Target_Spot
# 35             Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 36                       Tomato___Tomato_mosaic_virus
# 37                                   Tomato___healthy

# %%
os.mkdir('image data')

# %%
os.mkdir(os.path.join('image data', 'train'))
os.mkdir(os.path.join('image data', 'validation'))
os.mkdir(os.path.join('image data', 'test'))

# %%
train_path = os.path.join('image data/train')
val_path = os.path.join('image data/validation')
test_path = os.path.join('image data/test')

# %%
fnames['Tree type'].unique().tolist()
# Out:
# ['Apple',
#  'Cherry (including sour)',
#  'Corn (maize)',
#  'Grape',
#  'Orange',
#  'Peach',
#  'Pepper, bell',
#  'Potato',
#  'Squash',
#  'Strawberry',
#  'Tomato']

# %%
path_1 = os.path.join(train_path, 'Corn (maize)')
path_2 = os.path.join(test_path, 'Corn (maize)')
path_3 = os.path.join(val_path, 'Corn (maize)')

os.mkdir(path_1)
os.mkdir(path_2)
os.mkdir(path_3)

# %%
for disease, folder in fnames[fnames['Tree type'] == 'Corn (maize)'][['Disease', 'Folder']].values.tolist():
    # create directory to each disease
    sub_path_1 = os.path.join(path_1, disease.strip())
    sub_path_2 = os.path.join(path_2, disease.strip())
    sub_path_3 = os.path.join(path_3, disease.strip())

    os.mkdir(sub_path_1)
    os.mkdir(sub_path_2)
    os.mkdir(sub_path_3)

    # read data from source folder
    src = os.path.join(plant_village_dir, 'color', folder)
    image_count = len(os.listdir(src))
    test_img_count = image_count // 10
    val_img_count = (image_count - test_img_count) // 5
    train_img_count = image_count - (test_img_count + val_img_count)
    counts = [train_img_count, test_img_count, val_img_count]
    splits = [sub_path_1, sub_path_2, sub_path_3]

    for i in range(3):
        images = os.listdir(src)
        for j in images[:counts[i]]:
            shutil.copyfile(src=os.path.join(src, j),
                            dst=os.path.join(splits[i], j))

# %%
X = []
y = []
val_x = []
val_y = []
test_x = []
test_y = []

tree_path = os.path.join('image data/train', 'Corn (maize)')
tree_disease_types = os.listdir(tree_path)

for disease in tree_disease_types:
    img_name = os.listdir(os.path.join(tree_path, disease))

    for img in img_name:
        image_path = os.path.join(tree_path, disease, img)
        image = img_to_array(load_img(image_path, target_size=(56,56)))
        X.append(image)
        y.append(['Corn (maize)', disease])

# %%
tree_path = os.path.join('image data/validation', 'Corn (maize)')
tree_disease_types = os.listdir(tree_path)

for disease in tree_disease_types:
    img_name = os.listdir(os.path.join(tree_path, disease))

    for img in img_name:
        image_path = os.path.join(tree_path, disease, img)
        image = img_to_array(load_img(image_path, target_size=(56,56)))
        val_x.append(image)
        val_y.append(['Corn (maize)', disease])

# %%
tree_path = os.path.join('image data/test', 'Corn (maize)')
tree_disease_types = os.listdir(tree_path)

for disease in tree_disease_types:
    img_name = os.listdir(os.path.join(tree_path, disease))

    for img in img_name:
        image_path = os.path.join(tree_path, disease, img)
        image = img_to_array(load_img(image_path, target_size=(56,56)))
        test_x.append(image)
        test_y.append(['Corn (maize)', disease])

# %%
mlb = MultiLabelBinarizer()

X = np.array(X)
val_x = np.array(val_x)
y = mlb.fit_transform(y)
val_y = mlb.transform(val_y)
test_y = mlb.transform(test_y)
test_x = np.array(test_x)/255
val_x = val_x/255
X.shape, y.shape
# Out:
# ((2776, 56, 56, 3), (2776, 5))

# %%
generator = ImageDataGenerator(rescale=1. / 255,
                               rotation_range=15,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               horizontal_flip=True,
                               vertical_flip=True
                                    )
generator.fit(X)

# %%
check_pointer = ModelCheckpoint(filepath='exp_conv_20.hdf5',
                                save_best_only=True)

early_stop = EarlyStopping(monitor='val_loss',
                           patience=30,
                           min_delta=0,
                           restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.1,
                              patience=5,
                             cooldown=4)

# %%
def inception_module(x, filter_1x1, filter_3x3_reduce, filter_3x3, filter_5x5_reduce, filter_5x5, filters_pool_proj,
                     name=None):
    # reduction layer
    conv_3x3_reducer = Conv2D(filters=filter_3x3_reduce, kernel_size=(1, 1), activation=relu, padding='same')(x)
    conv_5x5_reducer = Conv2D(filters=filter_5x5_reduce, kernel_size=(1, 1), activation=relu, padding='same')(x)
    pool_3x3 = MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same')(x)

    # extraction layer
    conv_3x3 = Conv2D(filters=filter_3x3, kernel_size=(3, 3), activation=relu, padding='same')(conv_3x3_reducer)
    conv_5x5 = Conv2D(filters=filter_5x5, kernel_size=(5, 5), activation=relu, padding='same')(conv_5x5_reducer)
    conv_1x1_proj = Conv2D(filters=filters_pool_proj, kernel_size=(1, 1), activation=relu, padding='same')(pool_3x3)

    # projection layer
    proj = Conv2D(filters=filter_1x1, kernel_size=(1, 1), activation=relu, padding='same')(x)

    # output
    x = concatenate([proj, conv_1x1_proj, conv_3x3, conv_5x5], axis=3, name=name)

    return x

# %%
exp_input = Input(shape=(56,56,3))

# conv_7x7
x = Conv2D(filters=64, kernel_size=(7,7), padding='same', activation=relu)(exp_input)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(3,3), strides=(1,1))(x)

# conv_5x5
x = Conv2D(filters=192, kernel_size=(5,5), padding='same', activation=relu)(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(3,3), strides=(1,1))(x)

# inception block 1
x = inception_module(x,
                     filter_1x1=64,
                     filter_5x5_reduce=96,
                     filter_3x3=128,
                     filter_3x3_reduce=16,
                     filter_5x5=32,
                     filters_pool_proj=32,
                     name='inception_1a')
x = inception_module(x,
                     filter_1x1=96,
                     filter_5x5_reduce=128,
                     filter_3x3=160,
                     filter_3x3_reduce=32,
                     filter_5x5=48,
                     filters_pool_proj=64,
                     name='inception_1b')

# pooling
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

# inception block 2
x = inception_module(x,
                     filter_1x1=128,
                     filter_5x5_reduce=96,
                     filter_3x3=128,
                     filter_3x3_reduce=48,
                     filter_5x5=32,
                     filters_pool_proj=32,
                     name='inception_2a')
x = inception_module(x,
                     filter_1x1=160,
                     filter_5x5_reduce=112,
                     filter_3x3=160,
                     filter_3x3_reduce=32,
                     filter_5x5=64,
                     filters_pool_proj=64,
                     name='inception_2b')
x = inception_module(x,
                     filter_1x1=192,
                     filter_5x5_reduce=128,
                     filter_3x3=128,
                     filter_3x3_reduce=48,
                     filter_5x5=64,
                     filters_pool_proj=64,
                     name='inception_2c')
x = inception_module(x,
                     filter_1x1=256,
                     filter_5x5_reduce=160,
                     filter_3x3=160,
                     filter_3x3_reduce=32,
                     filter_5x5=96,
                     filters_pool_proj=96,
                     name='inception_2d')

# pooling
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

# conv 3x3
x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = Conv2D(filters=256, kernel_size=(3,3), activation=relu, padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2), padding='same')(x)

# flatten
x = Flatten()(x)

# output layer
x = Dense(units=1024, activation=relu)(x)
x = Dropout(0.5)(x)
x = Dense(units=1024, activation=relu)(x)
x = Dropout(0.5)(x)
exp_output = Dense(units=5, activation=sigmoid)(x)     # units 개수?????

exp_conv = Model(exp_input, exp_output)
exp_conv.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 56, 56, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 56, 56, 64)   9472        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 56, 56, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  max_pooling2d (MaxPooling2D)   (None, 54, 54, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 54, 54, 192)  307392      ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 54, 54, 192)  768        ['conv2d_1[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 52, 52, 192)  0          ['batch_normalization_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 52, 52, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 52, 52, 16)   3088        ['max_pooling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 52, 52, 96)   18528       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 52, 52, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 52, 52, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 52, 52, 128)  18560       ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 52, 52, 32)   76832       ['conv2d_3[0][0]']
#
#  inception_1a (Concatenate)     (None, 52, 52, 256)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 256)  0          ['inception_1a[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 52, 52, 32)   8224        ['inception_1a[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 52, 52, 128)  32896       ['inception_1a[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 52, 52, 96)   24672       ['inception_1a[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 52, 52, 64)   16448       ['max_pooling2d_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 52, 52, 160)  46240       ['conv2d_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 52, 52, 48)   153648      ['conv2d_9[0][0]']
#
#  inception_1b (Concatenate)     (None, 52, 52, 368)  0           ['conv2d_13[0][0]',
#                                                                   'conv2d_12[0][0]',
#                                                                   'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 52, 52, 368)  1472       ['inception_1b[0][0]']
#  rmalization)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 26, 26, 368)  0          ['batch_normalization_2[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 26, 26, 368)  0          ['max_pooling2d_4[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 26, 26, 48)   17712       ['max_pooling2d_4[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 26, 26, 96)   35424       ['max_pooling2d_4[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 26, 26, 128)  47232       ['max_pooling2d_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 26, 26, 32)   11808       ['max_pooling2d_5[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 26, 26, 128)  55424       ['conv2d_14[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 26, 26, 32)   76832       ['conv2d_15[0][0]']
#
#  inception_2a (Concatenate)     (None, 26, 26, 320)  0           ['conv2d_19[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_16[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 26, 26, 320)  0          ['inception_2a[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 26, 26, 32)   10272       ['inception_2a[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 26, 26, 112)  35952       ['inception_2a[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 26, 26, 160)  51360       ['inception_2a[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 26, 26, 64)   20544       ['max_pooling2d_6[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 26, 26, 160)  46240       ['conv2d_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 26, 26, 64)   179264      ['conv2d_21[0][0]']
#
#  inception_2b (Concatenate)     (None, 26, 26, 448)  0           ['conv2d_25[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_22[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 26, 26, 448)  0          ['inception_2b[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 26, 26, 48)   21552       ['inception_2b[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 26, 26, 128)  57472       ['inception_2b[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 26, 26, 192)  86208       ['inception_2b[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 26, 26, 64)   28736       ['max_pooling2d_7[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 26, 26, 128)  55424       ['conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 26, 26, 64)   204864      ['conv2d_27[0][0]']
#
#  inception_2c (Concatenate)     (None, 26, 26, 448)  0           ['conv2d_31[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_28[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 26, 26, 448)  0          ['inception_2c[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 26, 26, 32)   14368       ['inception_2c[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 26, 26, 160)  71840       ['inception_2c[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 26, 26, 256)  114944      ['inception_2c[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 26, 26, 96)   43104       ['max_pooling2d_8[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 26, 26, 160)  46240       ['conv2d_32[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 26, 26, 96)   384096      ['conv2d_33[0][0]']
#
#  inception_2d (Concatenate)     (None, 26, 26, 608)  0           ['conv2d_37[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_34[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 26, 26, 608)  2432       ['inception_2d[0][0]']
#  rmalization)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 13, 13, 608)  0          ['batch_normalization_3[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 13, 13, 256)  1401088     ['max_pooling2d_9[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 13, 13, 256)  590080      ['conv2d_38[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 13, 13, 256)  1024       ['conv2d_39[0][0]']
#  rmalization)
#
#  max_pooling2d_10 (MaxPooling2D  (None, 7, 7, 256)   0           ['batch_normalization_4[0][0]']
#  )
#
#  conv2d_40 (Conv2D)             (None, 7, 7, 256)    590080      ['max_pooling2d_10[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 7, 7, 256)    590080      ['conv2d_40[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 7, 7, 256)   1024        ['conv2d_41[0][0]']
#  rmalization)
#
#  max_pooling2d_11 (MaxPooling2D  (None, 4, 4, 256)   0           ['batch_normalization_5[0][0]']
#  )
#
#  conv2d_42 (Conv2D)             (None, 4, 4, 256)    590080      ['max_pooling2d_11[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 4, 4, 256)    590080      ['conv2d_42[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 4, 4, 256)   1024        ['conv2d_43[0][0]']
#  rmalization)
#
#  max_pooling2d_12 (MaxPooling2D  (None, 2, 2, 256)   0           ['batch_normalization_6[0][0]']
#  )
#
#  flatten (Flatten)              (None, 1024)         0           ['max_pooling2d_12[0][0]']
#
#  dense (Dense)                  (None, 1024)         1049600     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1024)         1049600     ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 5)            5125        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 8,915,253
# Trainable params: 8,911,253
# Non-trainable params: 4,000
# __________________________________________________________________________________________________

# %%
# plot_model(exp_conv,
#            to_file='baseline_conv_15_exp(VGGNet with INCEPTION).png',
#            show_shapes=True,
#            show_dtype=True,
#            show_layer_names=True)

# %%
exp_conv.compile(optimizer=Adam(),
                   loss=binary_crossentropy,
                   metrics=[Recall(), Precision(), 'accuracy'])

history = exp_conv.fit(generator.flow(X,y, batch_size=128), 
                        epochs=500, 
                        validation_data=(val_x,val_y),
                        callbacks=[early_stop, check_pointer, reduce_lr])
# Out:
# Epoch 1/500
# 22/22 [==============================] - 56s 1s/step - loss: 0.2944 - recall: 0.8442 - precision: 0.8705 - accuracy: 0.7158 - val_loss: 55.3398 - val_recall: 0.6553 - val_precision: 0.6558 - val_accuracy: 0.3251 - lr: 0.0010
# Epoch 2/500
# 22/22 [==============================] - 19s 873ms/step - loss: 0.1335 - recall: 0.9166 - precision: 0.9258 - accuracy: 0.7756 - val_loss: 3.2746 - val_recall: 0.6553 - val_precision: 0.6553 - val_accuracy: 0.6127 - lr: 0.0010
# Epoch 3/500
# 22/22 [==============================] - 20s 886ms/step - loss: 0.1095 - recall: 0.9362 - precision: 0.9388 - accuracy: 0.7939 - val_loss: 7.5249 - val_recall: 0.6546 - val_precision: 0.6546 - val_accuracy: 0.3092 - lr: 0.0010
# Epoch 4/500
# 22/22 [==============================] - 21s 932ms/step - loss: 0.0969 - recall: 0.9452 - precision: 0.9483 - accuracy: 0.7360 - val_loss: 1.8735 - val_recall: 0.6546 - val_precision: 0.6546 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 5/500
# 22/22 [==============================] - 19s 876ms/step - loss: 0.0876 - recall: 0.9552 - precision: 0.9558 - accuracy: 0.7666 - val_loss: 2.2490 - val_recall: 0.6546 - val_precision: 0.6546 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 6/500
# 22/22 [==============================] - 20s 893ms/step - loss: 0.0962 - recall: 0.9445 - precision: 0.9547 - accuracy: 0.7799 - val_loss: 1.2539 - val_recall: 0.6546 - val_precision: 0.6546 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 7/500
# 22/22 [==============================] - 19s 875ms/step - loss: 0.0760 - recall: 0.9588 - precision: 0.9615 - accuracy: 0.8404 - val_loss: 1.6738 - val_recall: 0.6546 - val_precision: 0.6546 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 8/500
# 22/22 [==============================] - 20s 911ms/step - loss: 0.0710 - recall: 0.9649 - precision: 0.9680 - accuracy: 0.7698 - val_loss: 0.9801 - val_recall: 0.6590 - val_precision: 0.6575 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 9/500
# 22/22 [==============================] - 19s 882ms/step - loss: 0.0695 - recall: 0.9620 - precision: 0.9653 - accuracy: 0.8296 - val_loss: 1.6939 - val_recall: 0.6510 - val_precision: 0.6510 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 10/500
# 22/22 [==============================] - 19s 882ms/step - loss: 0.0670 - recall: 0.9701 - precision: 0.9703 - accuracy: 0.7918 - val_loss: 2.0613 - val_recall: 0.6510 - val_precision: 0.6510 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 11/500
# 22/22 [==============================] - 19s 879ms/step - loss: 0.0646 - recall: 0.9688 - precision: 0.9715 - accuracy: 0.7954 - val_loss: 1.0194 - val_recall: 0.7132 - val_precision: 0.7101 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 12/500
# 22/22 [==============================] - 20s 907ms/step - loss: 0.0587 - recall: 0.9696 - precision: 0.9706 - accuracy: 0.7994 - val_loss: 0.7512 - val_recall: 0.7059 - val_precision: 0.6989 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 13/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0566 - recall: 0.9710 - precision: 0.9742 - accuracy: 0.8206 - val_loss: 0.8041 - val_recall: 0.6987 - val_precision: 0.7002 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 14/500
# 22/22 [==============================] - 20s 907ms/step - loss: 0.0589 - recall: 0.9679 - precision: 0.9686 - accuracy: 0.7633 - val_loss: 0.6581 - val_recall: 0.6951 - val_precision: 0.7195 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 15/500
# 22/22 [==============================] - 19s 883ms/step - loss: 0.0511 - recall: 0.9764 - precision: 0.9762 - accuracy: 0.7893 - val_loss: 1.4204 - val_recall: 0.6510 - val_precision: 0.6515 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 16/500
# 22/22 [==============================] - 19s 882ms/step - loss: 0.0463 - recall: 0.9742 - precision: 0.9758 - accuracy: 0.7803 - val_loss: 2.3482 - val_recall: 0.6510 - val_precision: 0.6510 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 17/500
# 22/22 [==============================] - 19s 882ms/step - loss: 0.0635 - recall: 0.9681 - precision: 0.9681 - accuracy: 0.7896 - val_loss: 1.5553 - val_recall: 0.6900 - val_precision: 0.6915 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 18/500
# 22/22 [==============================] - 21s 942ms/step - loss: 0.0487 - recall: 0.9750 - precision: 0.9760 - accuracy: 0.7835 - val_loss: 1.6886 - val_recall: 0.7009 - val_precision: 0.7034 - val_accuracy: 0.5578 - lr: 0.0010
# Epoch 19/500
# 22/22 [==============================] - 19s 870ms/step - loss: 0.0540 - recall: 0.9715 - precision: 0.9715 - accuracy: 0.8487 - val_loss: 1.6547 - val_recall: 0.7861 - val_precision: 0.7771 - val_accuracy: 0.6604 - lr: 0.0010
# Epoch 20/500
# 22/22 [==============================] - 22s 998ms/step - loss: 0.0495 - recall: 0.9755 - precision: 0.9778 - accuracy: 0.8469 - val_loss: 0.5557 - val_recall: 0.8353 - val_precision: 0.8432 - val_accuracy: 0.6373 - lr: 1.0000e-04
# Epoch 21/500
# 22/22 [==============================] - 20s 907ms/step - loss: 0.0398 - recall: 0.9782 - precision: 0.9800 - accuracy: 0.8491 - val_loss: 0.2100 - val_recall: 0.9126 - val_precision: 0.9073 - val_accuracy: 0.5997 - lr: 1.0000e-04
# Epoch 22/500
# 22/22 [==============================] - 20s 891ms/step - loss: 0.0376 - recall: 0.9822 - precision: 0.9815 - accuracy: 0.8408 - val_loss: 0.1927 - val_recall: 0.9126 - val_precision: 0.9067 - val_accuracy: 0.5939 - lr: 1.0000e-04
# Epoch 23/500
# 22/22 [==============================] - 20s 899ms/step - loss: 0.0336 - recall: 0.9825 - precision: 0.9847 - accuracy: 0.8476 - val_loss: 0.1502 - val_recall: 0.9198 - val_precision: 0.9185 - val_accuracy: 0.6373 - lr: 1.0000e-04
# Epoch 24/500
# 22/22 [==============================] - 20s 910ms/step - loss: 0.0364 - recall: 0.9820 - precision: 0.9827 - accuracy: 0.8498 - val_loss: 0.1065 - val_recall: 0.9436 - val_precision: 0.9409 - val_accuracy: 0.6792 - lr: 1.0000e-04
# Epoch 25/500
# 22/22 [==============================] - 20s 905ms/step - loss: 0.0306 - recall: 0.9849 - precision: 0.9849 - accuracy: 0.8494 - val_loss: 0.0674 - val_recall: 0.9675 - val_precision: 0.9612 - val_accuracy: 0.7066 - lr: 1.0000e-04
# Epoch 26/500
# 22/22 [==============================] - 19s 878ms/step - loss: 0.0303 - recall: 0.9845 - precision: 0.9852 - accuracy: 0.8512 - val_loss: 0.1160 - val_recall: 0.9494 - val_precision: 0.9453 - val_accuracy: 0.7529 - lr: 1.0000e-04
# Epoch 27/500
# 22/22 [==============================] - 19s 876ms/step - loss: 0.0287 - recall: 0.9870 - precision: 0.9872 - accuracy: 0.8483 - val_loss: 0.0870 - val_recall: 0.9581 - val_precision: 0.9567 - val_accuracy: 0.7861 - lr: 1.0000e-04
# Epoch 28/500
# 22/22 [==============================] - 19s 875ms/step - loss: 0.0278 - recall: 0.9874 - precision: 0.9874 - accuracy: 0.8469 - val_loss: 0.1647 - val_recall: 0.9321 - val_precision: 0.9314 - val_accuracy: 0.8223 - lr: 1.0000e-04
# Epoch 29/500
# 22/22 [==============================] - 19s 871ms/step - loss: 0.0244 - recall: 0.9888 - precision: 0.9888 - accuracy: 0.8527 - val_loss: 0.1479 - val_recall: 0.9364 - val_precision: 0.9364 - val_accuracy: 0.8367 - lr: 1.0000e-04
# Epoch 30/500
# 22/22 [==============================] - 19s 874ms/step - loss: 0.0299 - recall: 0.9861 - precision: 0.9860 - accuracy: 0.8501 - val_loss: 0.0701 - val_recall: 0.9675 - val_precision: 0.9675 - val_accuracy: 0.8613 - lr: 1.0000e-04
# Epoch 31/500
# 22/22 [==============================] - 20s 901ms/step - loss: 0.0246 - recall: 0.9890 - precision: 0.9881 - accuracy: 0.8537 - val_loss: 0.0659 - val_recall: 0.9711 - val_precision: 0.9697 - val_accuracy: 0.8627 - lr: 1.0000e-05
# Epoch 32/500
# 22/22 [==============================] - 19s 878ms/step - loss: 0.0276 - recall: 0.9874 - precision: 0.9877 - accuracy: 0.8527 - val_loss: 0.0697 - val_recall: 0.9689 - val_precision: 0.9668 - val_accuracy: 0.8642 - lr: 1.0000e-05
# Epoch 33/500
# 22/22 [==============================] - 19s 880ms/step - loss: 0.0240 - recall: 0.9876 - precision: 0.9879 - accuracy: 0.8541 - val_loss: 0.0755 - val_recall: 0.9653 - val_precision: 0.9646 - val_accuracy: 0.8656 - lr: 1.0000e-05
# Epoch 34/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0247 - recall: 0.9878 - precision: 0.9890 - accuracy: 0.8516 - val_loss: 0.0829 - val_recall: 0.9646 - val_precision: 0.9632 - val_accuracy: 0.8671 - lr: 1.0000e-05
# Epoch 35/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0234 - recall: 0.9883 - precision: 0.9888 - accuracy: 0.8487 - val_loss: 0.0822 - val_recall: 0.9668 - val_precision: 0.9654 - val_accuracy: 0.8671 - lr: 1.0000e-05
# Epoch 36/500
# 22/22 [==============================] - 19s 883ms/step - loss: 0.0250 - recall: 0.9888 - precision: 0.9892 - accuracy: 0.8501 - val_loss: 0.0872 - val_recall: 0.9639 - val_precision: 0.9639 - val_accuracy: 0.8671 - lr: 1.0000e-05
# Epoch 37/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0230 - recall: 0.9874 - precision: 0.9886 - accuracy: 0.8505 - val_loss: 0.0976 - val_recall: 0.9603 - val_precision: 0.9575 - val_accuracy: 0.8671 - lr: 1.0000e-05
# Epoch 38/500
# 22/22 [==============================] - 19s 882ms/step - loss: 0.0248 - recall: 0.9892 - precision: 0.9881 - accuracy: 0.8555 - val_loss: 0.1100 - val_recall: 0.9559 - val_precision: 0.9552 - val_accuracy: 0.8671 - lr: 1.0000e-05
# Epoch 39/500
# 22/22 [==============================] - 19s 879ms/step - loss: 0.0230 - recall: 0.9883 - precision: 0.9892 - accuracy: 0.8512 - val_loss: 0.0986 - val_recall: 0.9588 - val_precision: 0.9588 - val_accuracy: 0.8671 - lr: 1.0000e-06
# Epoch 40/500
# 22/22 [==============================] - 19s 879ms/step - loss: 0.0220 - recall: 0.9894 - precision: 0.9904 - accuracy: 0.8509 - val_loss: 0.0898 - val_recall: 0.9632 - val_precision: 0.9625 - val_accuracy: 0.8671 - lr: 1.0000e-06
# Epoch 41/500
# 22/22 [==============================] - 19s 875ms/step - loss: 0.0259 - recall: 0.9874 - precision: 0.9877 - accuracy: 0.8516 - val_loss: 0.0833 - val_recall: 0.9660 - val_precision: 0.9653 - val_accuracy: 0.8671 - lr: 1.0000e-06
# Epoch 42/500
# 22/22 [==============================] - 19s 878ms/step - loss: 0.0241 - recall: 0.9901 - precision: 0.9901 - accuracy: 0.8541 - val_loss: 0.0785 - val_recall: 0.9660 - val_precision: 0.9660 - val_accuracy: 0.8671 - lr: 1.0000e-06
# Epoch 43/500
# 22/22 [==============================] - 19s 880ms/step - loss: 0.0233 - recall: 0.9887 - precision: 0.9890 - accuracy: 0.8469 - val_loss: 0.0755 - val_recall: 0.9668 - val_precision: 0.9668 - val_accuracy: 0.8671 - lr: 1.0000e-06
# Epoch 44/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0236 - recall: 0.9892 - precision: 0.9885 - accuracy: 0.8519 - val_loss: 0.0727 - val_recall: 0.9682 - val_precision: 0.9675 - val_accuracy: 0.8671 - lr: 1.0000e-06
# Epoch 45/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0220 - recall: 0.9890 - precision: 0.9888 - accuracy: 0.8509 - val_loss: 0.0723 - val_recall: 0.9682 - val_precision: 0.9675 - val_accuracy: 0.8671 - lr: 1.0000e-06
# Epoch 46/500
# 22/22 [==============================] - 19s 882ms/step - loss: 0.0234 - recall: 0.9883 - precision: 0.9888 - accuracy: 0.8505 - val_loss: 0.0683 - val_recall: 0.9711 - val_precision: 0.9711 - val_accuracy: 0.8671 - lr: 1.0000e-06
# Epoch 47/500
# 22/22 [==============================] - 19s 883ms/step - loss: 0.0232 - recall: 0.9887 - precision: 0.9885 - accuracy: 0.8541 - val_loss: 0.0670 - val_recall: 0.9718 - val_precision: 0.9711 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 48/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0218 - recall: 0.9896 - precision: 0.9887 - accuracy: 0.8516 - val_loss: 0.0659 - val_recall: 0.9733 - val_precision: 0.9712 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 49/500
# 22/22 [==============================] - 20s 906ms/step - loss: 0.0231 - recall: 0.9914 - precision: 0.9910 - accuracy: 0.8512 - val_loss: 0.0652 - val_recall: 0.9733 - val_precision: 0.9712 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 50/500
# 22/22 [==============================] - 20s 904ms/step - loss: 0.0251 - recall: 0.9878 - precision: 0.9876 - accuracy: 0.8501 - val_loss: 0.0638 - val_recall: 0.9740 - val_precision: 0.9726 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 51/500
# 22/22 [==============================] - 20s 905ms/step - loss: 0.0250 - recall: 0.9876 - precision: 0.9883 - accuracy: 0.8523 - val_loss: 0.0632 - val_recall: 0.9740 - val_precision: 0.9733 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 52/500
# 22/22 [==============================] - 20s 904ms/step - loss: 0.0238 - recall: 0.9892 - precision: 0.9890 - accuracy: 0.8498 - val_loss: 0.0628 - val_recall: 0.9740 - val_precision: 0.9733 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 53/500
# 22/22 [==============================] - 20s 902ms/step - loss: 0.0251 - recall: 0.9887 - precision: 0.9894 - accuracy: 0.8473 - val_loss: 0.0628 - val_recall: 0.9740 - val_precision: 0.9740 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 54/500
# 22/22 [==============================] - 20s 906ms/step - loss: 0.0210 - recall: 0.9897 - precision: 0.9892 - accuracy: 0.8534 - val_loss: 0.0622 - val_recall: 0.9747 - val_precision: 0.9740 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 55/500
# 22/22 [==============================] - 20s 907ms/step - loss: 0.0253 - recall: 0.9879 - precision: 0.9885 - accuracy: 0.8552 - val_loss: 0.0621 - val_recall: 0.9747 - val_precision: 0.9740 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 56/500
# 22/22 [==============================] - 20s 906ms/step - loss: 0.0218 - recall: 0.9890 - precision: 0.9901 - accuracy: 0.8516 - val_loss: 0.0613 - val_recall: 0.9762 - val_precision: 0.9747 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 57/500
# 22/22 [==============================] - 20s 906ms/step - loss: 0.0229 - recall: 0.9896 - precision: 0.9896 - accuracy: 0.8527 - val_loss: 0.0608 - val_recall: 0.9762 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 58/500
# 22/22 [==============================] - 19s 878ms/step - loss: 0.0244 - recall: 0.9883 - precision: 0.9876 - accuracy: 0.8509 - val_loss: 0.0611 - val_recall: 0.9762 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 59/500
# 22/22 [==============================] - 20s 905ms/step - loss: 0.0238 - recall: 0.9878 - precision: 0.9879 - accuracy: 0.8476 - val_loss: 0.0607 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 60/500
# 22/22 [==============================] - 20s 904ms/step - loss: 0.0242 - recall: 0.9883 - precision: 0.9894 - accuracy: 0.8537 - val_loss: 0.0605 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 61/500
# 22/22 [==============================] - 20s 904ms/step - loss: 0.0228 - recall: 0.9892 - precision: 0.9890 - accuracy: 0.8548 - val_loss: 0.0603 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 62/500
# 22/22 [==============================] - 19s 878ms/step - loss: 0.0242 - recall: 0.9892 - precision: 0.9895 - accuracy: 0.8498 - val_loss: 0.0604 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 63/500
# 22/22 [==============================] - 19s 878ms/step - loss: 0.0191 - recall: 0.9915 - precision: 0.9922 - accuracy: 0.8548 - val_loss: 0.0605 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 64/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0240 - recall: 0.9890 - precision: 0.9899 - accuracy: 0.8552 - val_loss: 0.0604 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 65/500
# 22/22 [==============================] - 20s 906ms/step - loss: 0.0238 - recall: 0.9888 - precision: 0.9883 - accuracy: 0.8483 - val_loss: 0.0603 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 66/500
# 22/22 [==============================] - 20s 906ms/step - loss: 0.0207 - recall: 0.9899 - precision: 0.9906 - accuracy: 0.8552 - val_loss: 0.0600 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 67/500
# 22/22 [==============================] - 20s 914ms/step - loss: 0.0234 - recall: 0.9888 - precision: 0.9899 - accuracy: 0.8491 - val_loss: 0.0599 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 68/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0200 - recall: 0.9899 - precision: 0.9913 - accuracy: 0.8512 - val_loss: 0.0600 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 69/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0221 - recall: 0.9908 - precision: 0.9905 - accuracy: 0.8545 - val_loss: 0.0601 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 70/500
# 22/22 [==============================] - 20s 907ms/step - loss: 0.0295 - recall: 0.9860 - precision: 0.9868 - accuracy: 0.8505 - val_loss: 0.0596 - val_recall: 0.9769 - val_precision: 0.9762 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 71/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0232 - recall: 0.9896 - precision: 0.9894 - accuracy: 0.8534 - val_loss: 0.0598 - val_recall: 0.9769 - val_precision: 0.9762 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 72/500
# 22/22 [==============================] - 19s 882ms/step - loss: 0.0244 - recall: 0.9876 - precision: 0.9885 - accuracy: 0.8509 - val_loss: 0.0599 - val_recall: 0.9769 - val_precision: 0.9762 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 73/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0222 - recall: 0.9901 - precision: 0.9908 - accuracy: 0.8498 - val_loss: 0.0601 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 74/500
# 22/22 [==============================] - 19s 882ms/step - loss: 0.0252 - recall: 0.9881 - precision: 0.9890 - accuracy: 0.8516 - val_loss: 0.0607 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 75/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0211 - recall: 0.9896 - precision: 0.9906 - accuracy: 0.8555 - val_loss: 0.0605 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-07
# Epoch 76/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0223 - recall: 0.9901 - precision: 0.9896 - accuracy: 0.8519 - val_loss: 0.0605 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-08
# Epoch 77/500
# 22/22 [==============================] - 19s 882ms/step - loss: 0.0216 - recall: 0.9896 - precision: 0.9906 - accuracy: 0.8523 - val_loss: 0.0606 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-08
# Epoch 78/500
# 22/22 [==============================] - 19s 882ms/step - loss: 0.0217 - recall: 0.9896 - precision: 0.9912 - accuracy: 0.8516 - val_loss: 0.0606 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-08
# Epoch 79/500
# 22/22 [==============================] - 19s 883ms/step - loss: 0.0239 - recall: 0.9874 - precision: 0.9881 - accuracy: 0.8476 - val_loss: 0.0610 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-08
# Epoch 80/500
# 22/22 [==============================] - 19s 884ms/step - loss: 0.0269 - recall: 0.9881 - precision: 0.9881 - accuracy: 0.8519 - val_loss: 0.0613 - val_recall: 0.9762 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-08
# Epoch 81/500
# 22/22 [==============================] - 19s 883ms/step - loss: 0.0247 - recall: 0.9890 - precision: 0.9897 - accuracy: 0.8530 - val_loss: 0.0614 - val_recall: 0.9762 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-08
# Epoch 82/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0202 - recall: 0.9905 - precision: 0.9912 - accuracy: 0.8534 - val_loss: 0.0610 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-08
# Epoch 83/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0255 - recall: 0.9881 - precision: 0.9897 - accuracy: 0.8509 - val_loss: 0.0609 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-08
# Epoch 84/500
# 22/22 [==============================] - 19s 878ms/step - loss: 0.0234 - recall: 0.9894 - precision: 0.9897 - accuracy: 0.8530 - val_loss: 0.0607 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-09
# Epoch 85/500
# 22/22 [==============================] - 19s 877ms/step - loss: 0.0208 - recall: 0.9903 - precision: 0.9903 - accuracy: 0.8548 - val_loss: 0.0605 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-09
# Epoch 86/500
# 22/22 [==============================] - 19s 879ms/step - loss: 0.0221 - recall: 0.9894 - precision: 0.9885 - accuracy: 0.8519 - val_loss: 0.0608 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-09
# Epoch 87/500
# 22/22 [==============================] - 19s 880ms/step - loss: 0.0234 - recall: 0.9885 - precision: 0.9876 - accuracy: 0.8563 - val_loss: 0.0609 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-09
# Epoch 88/500
# 22/22 [==============================] - 19s 879ms/step - loss: 0.0224 - recall: 0.9890 - precision: 0.9894 - accuracy: 0.8548 - val_loss: 0.0611 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-09
# Epoch 89/500
# 22/22 [==============================] - 19s 882ms/step - loss: 0.0184 - recall: 0.9923 - precision: 0.9924 - accuracy: 0.8480 - val_loss: 0.0612 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-09
# Epoch 90/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0229 - recall: 0.9901 - precision: 0.9906 - accuracy: 0.8530 - val_loss: 0.0609 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-09
# Epoch 91/500
# 22/22 [==============================] - 19s 882ms/step - loss: 0.0265 - recall: 0.9874 - precision: 0.9877 - accuracy: 0.8534 - val_loss: 0.0607 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-09
# Epoch 92/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0241 - recall: 0.9897 - precision: 0.9903 - accuracy: 0.8523 - val_loss: 0.0608 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-10
# Epoch 93/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0214 - recall: 0.9894 - precision: 0.9890 - accuracy: 0.8494 - val_loss: 0.0611 - val_recall: 0.9762 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-10
# Epoch 94/500
# 22/22 [==============================] - 19s 884ms/step - loss: 0.0219 - recall: 0.9897 - precision: 0.9901 - accuracy: 0.8530 - val_loss: 0.0610 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-10
# Epoch 95/500
# 22/22 [==============================] - 19s 883ms/step - loss: 0.0253 - recall: 0.9870 - precision: 0.9869 - accuracy: 0.8512 - val_loss: 0.0610 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-10
# Epoch 96/500
# 22/22 [==============================] - 19s 885ms/step - loss: 0.0210 - recall: 0.9888 - precision: 0.9901 - accuracy: 0.8530 - val_loss: 0.0609 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-10
# Epoch 97/500
# 22/22 [==============================] - 19s 882ms/step - loss: 0.0190 - recall: 0.9908 - precision: 0.9917 - accuracy: 0.8534 - val_loss: 0.0606 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-10
# Epoch 98/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0231 - recall: 0.9874 - precision: 0.9886 - accuracy: 0.8530 - val_loss: 0.0607 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-10
# Epoch 99/500
# 22/22 [==============================] - 19s 877ms/step - loss: 0.0243 - recall: 0.9897 - precision: 0.9901 - accuracy: 0.8498 - val_loss: 0.0609 - val_recall: 0.9769 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-10
# Epoch 100/500
# 22/22 [==============================] - 19s 881ms/step - loss: 0.0237 - recall: 0.9892 - precision: 0.9895 - accuracy: 0.8512 - val_loss: 0.0609 - val_recall: 0.9762 - val_precision: 0.9755 - val_accuracy: 0.8671 - lr: 1.0000e-11

# %%
exp_conv.evaluate(test_x,test_y)
# Out:
# 12/12 [==============================] - 2s 62ms/step - loss: 0.0692 - recall: 0.9714 - precision: 0.9701 - accuracy: 0.8672
# [0.06921372562646866, 0.9713541865348816, 0.9700910449028015, 0.8671875]

# %%
exp_conv.predict(test_x)
# Out:
# array([[8.1880701e-01, 8.2884048e-04, 9.9998498e-01, 1.8791620e-01,
#         2.9433882e-04],
#        [4.5464005e-02, 8.8082656e-05, 9.9999344e-01, 9.5903891e-01,
#         1.1495144e-04],
#        [5.3414800e-03, 3.7104435e-06, 9.9999988e-01, 9.9503493e-01,
#         9.0271669e-06],
#        ...,
#        [1.7550686e-22, 1.0000000e+00, 1.0000000e+00, 1.6591913e-19,
#         9.5581396e-22],
#        [9.5702161e-22, 1.0000000e+00, 1.0000000e+00, 6.9335282e-19,
#         4.2848869e-21],
#        [2.6440615e-16, 1.0000000e+00, 1.0000000e+00, 1.1215849e-14,
#         4.6322840e-16]], dtype=float32)

# %%
figure, axes = plt.subplots(nrows=1, ncols=3, figsize=[9, 3], dpi=100)
axes = axes.ravel()
epochs = list(range(len(history.history['loss'])))

sns.lineplot(x=epochs, y=history.history['loss'], ax=axes[0],label='loss')
sns.lineplot(x=epochs, y=history.history['val_loss'], ax=axes[0],label='val loss')
sns.lineplot(x=epochs, y=history.history['precision'], ax=axes[1],label='precision')
sns.lineplot(x=epochs, y=history.history['val_precision'], ax=axes[1],label='val precision')
sns.lineplot(x=epochs, y=history.history['recall'], color='#025918', ax=axes[1],label='recall')
sns.lineplot(x=epochs, y=history.history['val_recall'], color='#D9B504',ax=axes[1],label='val recall')
sns.lineplot(x=epochs, y=history.history['accuracy'], ax=axes[2],label='accuracy')
sns.lineplot(x=epochs, y=history.history['val_accuracy'], ax=axes[2],label='val accuracy')
axes[0].set_xlabel('epoch')
axes[0].set_ylabel('loss')
axes[1].set_xlabel('epoch')
axes[1].set_ylabel('precision and recall')
axes[2].set_xlabel('epoch')
axes[2].set_ylabel('accuracy')
plt.savefig('VGGNet_base_conv_train_history_with_cassava.png')
plt.show()

# %%
figure, axes = plt.subplots(nrows=1, ncols=2, figsize=[6, 3], dpi=100)
axes = axes.ravel()

sns.lineplot(x=epochs, y=history.history['lr'], ax=axes[0],label='learning rate')
sns.lineplot(x=history.history['lr'], y=history.history['val_accuracy'], ax=axes[1],label='accuracy & lr')
axes[0].set_xlabel('epoch')
axes[0].set_ylabel('learning rate')
axes[1].set_xlabel('learning rate')
axes[1].set_ylabel('accuracy')

plt.savefig('VGGNet_base_conv_lr_history_4.png')
plt.show()

# %%
# Plot confusion matrix
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=[15, 10], dpi=100)
axes = axes.ravel()

preds = np.where(exp_conv.predict(test_x) < 0.65, 0, 1)
confusion = multilabel_confusion_matrix(test_y, preds)

for i, (label, matrix) in enumerate(zip(mlb.classes_, confusion)):
    labels = [f'not_{label}', label]
    xlabels = [f'p_not_{label}', f'p_{label}']
    sns.heatmap(matrix, annot=True, square=True, fmt='d', cbar=False, cmap='Blues',
                xticklabels=xlabels, yticklabels=labels, linecolor='black', linewidth=1,
                ax=axes[i])
    axes[i].set_title(labels[0])

plt.savefig('VGGNet_base_conv_4_cm.png')
plt.show()

# %%
exp_conv.save('/content/drive/MyDrive/Corn (maize)(0.0596).hdf5')

# %%
mlb.classes_
# Out:
# array(['Cercospora leaf spot Gray leaf spot', 'Common rust',
#        'Corn (maize)', 'Northern Leaf Blight', 'healthy'], dtype=object)

# %%
exp_conv.predict(test_x[200:201])
# Out:
# array([[4.1068852e-06, 1.3589874e-07, 1.0000000e+00, 7.8329613e-06,
#         9.9999154e-01]], dtype=float32)

# %%
fig, axes = plt.subplots(nrows=5, ncols=2,figsize = (8, 24))
preds = exp_conv.predict(test_x[200:210])
axes = axes.ravel()

for i in range(len(preds)):
    p = zip(list(mlb.classes_), list(preds[i]))
    p = sorted(list(p), key = lambda z: z[1], reverse = True)[:2]
    axes[i].imshow(test_x[200+i])
    axes[i].set_title(f'{p[0][0]}: {round(p[0][1] * 100, 2)}% \n {p[1][0]}: {round(p[1][1] * 100, 2)}%')

# %%
pd.to_pickle(pd.DataFrame(history.history), 'VGGNet_base_conv_lr_history.pkl')

# %%
model_path = '/content/drive/MyDrive/Corn (maize)(0.0596).hdf5'
file_path = '/content/다운로드 (1).jpeg'

# %%
model = load_model(model_path)

# %%
img = load_img(file_path,target_size=(56,56))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=56x56 at 0x7EFC4864C0D0>

# %%
img_arr = img_to_array(img)

# %%
img_arr.shape
# Out:
# (56, 56, 3)

# %%
res_img_arr = np.reshape(img_arr,(1,56,56,3))
res_img_arr
# Out:
# array([[[[104., 137., 126.],
#          [122., 151., 169.],
#          [125., 157., 152.],
#          ...,
#          [220., 231., 152.],
#          [215., 220., 156.],
#          [226., 214., 176.]],
#
#         [[ 94., 126., 125.],
#          [116., 149., 142.],
#          [130., 161., 164.],
#          ...,
#          [192., 206., 108.],
#          [201., 199., 122.],
#          [197., 216., 108.]],
#
#         [[133., 163., 171.],
#          [118., 152., 138.],
#          [114., 144., 152.],
#          ...,
#          [225., 230., 163.],
#          [236., 228., 182.],
#          [211., 219., 118.]],
#
#         ...,
#
#         [[119., 143., 119.],
#          [124., 147., 127.],
#          [126., 148., 135.],
#          ...,
#          [ 53.,  94.,   2.],
#          [ 49.,  89.,   1.],
#          [ 50.,  90.,   1.]],
#
#         [[112., 138., 101.],
#          [124., 149., 119.],
#          [130., 154., 132.],
#          ...,
#          [ 52.,  91.,   0.],
#          [ 50.,  88.,   1.],
#          [ 51.,  89.,   2.]],
#
#         [[ 74., 102.,  54.],
#          [ 73., 101.,  52.],
#          [ 82., 111.,  57.],
#          ...,
#          [ 53.,  87.,   1.],
#          [ 53.,  87.,   1.],
#          [ 53.,  87.,   1.]]]], dtype=float32)

# %%
pred = model.predict(res_img_arr)
pred
# Out:
# WARNING:tensorflow:5 out of the last 30 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc49319830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[0., 1., 1., 0., 0.]], dtype=float32)

# %%
pred[0][1:].argmax()
# Out:
# 0

# %%
mlb.classes_
# Out:
# array(['Cercospora leaf spot Gray leaf spot', 'Common rust',
#        'Corn (maize)', 'Northern Leaf Blight', 'healthy'], dtype=object)

# %%
def test(file_path):
  model = load_model(model_path)
  img = load_img(file_path,target_size=(56,56))
  img_arr = img_to_array(img)
  res_img_arr = np.reshape(img_arr,(1,56,56,3))/255
  pred = model.predict(res_img_arr)
  return mlb.classes_[1:][pred[0][1:].argmax()], round(pred[0][pred[0][1:].argmax()+1]*100,2), pred[0][0]

# %%
test(file_path)
# Out:
# WARNING:tensorflow:6 out of the last 32 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efc49319320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ('Corn (maize)', 99.95, 0.023654237)
