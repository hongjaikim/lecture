# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !git clone https://github.com/taehojo/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 21 (delta 3), reused 20 (delta 2), pack-reused 0
# Unpacking objects: 100% (21/21), done.

# %%
df = pd.read_csv('./data/pima-indians-diabetes3.csv')

# %%
df.head()
# Out:
#    pregnant  plasma  pressure  thickness  insulin   bmi  pedigree  age  \
# 0         6     148        72         35        0  33.6     0.627   50
# 1         1      85        66         29        0  26.6     0.351   31
# 2         8     183        64          0        0  23.3     0.672   32
# 3         1      89        66         23       94  28.1     0.167   21
# 4         0     137        40         35      168  43.1     2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
df['diabetes'].value_counts()
# Out:
# 0    500
# 1    268
# Name: diabetes, dtype: int64

# %%
df.describe()
# Out:
#          pregnant      plasma    pressure   thickness     insulin         bmi  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#          pedigree         age    diabetes
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# 50%      0.372500   29.000000    0.000000
# 75%      0.626250   41.000000    1.000000
# max      2.420000   81.000000    1.000000

# %%
df.corr()
# Out:
#            pregnant    plasma  pressure  thickness   insulin       bmi  \
# pregnant   1.000000  0.129459  0.141282  -0.081672 -0.073535  0.017683
# plasma     0.129459  1.000000  0.152590   0.057328  0.331357  0.221071
# pressure   0.141282  0.152590  1.000000   0.207371  0.088933  0.281805
# thickness -0.081672  0.057328  0.207371   1.000000  0.436783  0.392573
# insulin   -0.073535  0.331357  0.088933   0.436783  1.000000  0.197859
# bmi        0.017683  0.221071  0.281805   0.392573  0.197859  1.000000
# pedigree  -0.033523  0.137337  0.041265   0.183928  0.185071  0.140647
# age        0.544341  0.263514  0.239528  -0.113970 -0.042163  0.036242
# diabetes   0.221898  0.466581  0.065068   0.074752  0.130548  0.292695
#
#            pedigree       age  diabetes
# pregnant  -0.033523  0.544341  0.221898
# plasma     0.137337  0.263514  0.466581
# pressure   0.041265  0.239528  0.065068
# thickness  0.183928 -0.113970  0.074752
# insulin    0.185071 -0.042163  0.130548
# bmi        0.140647  0.036242  0.292695
# pedigree   1.000000  0.033561  0.173844
# age        0.033561  1.000000  0.238356
# diabetes   0.173844  0.238356  1.000000

# %%
colormap = plt.cm.gist_heat
plt.figure(figsize=(12,12))

# %%
sns.heatmap(df.corr(),linewidths=0.1,vmax=0.5,cmap=colormap,linecolor='white',annot=True)
plt.show()

# %%
plt.hist(x=[df.plasma[df.diabetes==0],df.plasma[df.diabetes==1]],bins=30,histtype='barstacked',label=['normal','diabetes'])
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
plt.hist(x=[df.bmi[df.diabetes==0],df.bmi[df.diabetes==1]],bins=30,histtype='barstacked',label=['normal','diabetes'])
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).size
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X=df.iloc[:,0:8]
y=df.iloc[:,8]

# %%
model = Sequential()
model.add(Dense(12,input_dim=8,activation='relu',name='Dense_1'))
model.add(Dense(8,activation='relu',name='Dense_2'))
model.add(Dense(1,activation='sigmoid',name='Dense_3'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense_1 (Dense)             (None, 12)                108
#
#  Dense_2 (Dense)             (None, 8)                 104
#
#  Dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',
              metrics=['accuracy'])

history = model.fit(X,y,epochs=100,batch_size=5)
# Out:
# Epoch 1/100
# 154/154 [==============================] - 2s 3ms/step - loss: 3.9957 - accuracy: 0.5573
# Epoch 2/100
# 154/154 [==============================] - 0s 3ms/step - loss: 1.4430 - accuracy: 0.5690
# Epoch 3/100
# 154/154 [==============================] - 0s 3ms/step - loss: 1.1148 - accuracy: 0.5990
# Epoch 4/100
# 154/154 [==============================] - 0s 3ms/step - loss: 1.0109 - accuracy: 0.6211
# Epoch 5/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.9042 - accuracy: 0.6276
# Epoch 6/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.8272 - accuracy: 0.6237
# Epoch 7/100
# 154/154 [==============================] - 1s 4ms/step - loss: 0.7900 - accuracy: 0.6042
# Epoch 8/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.7616 - accuracy: 0.6406
# Epoch 9/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.7092 - accuracy: 0.6615
# Epoch 10/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6863 - accuracy: 0.6562
# Epoch 11/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.7046 - accuracy: 0.6432
# Epoch 12/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6720 - accuracy: 0.6523
# Epoch 13/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.6570 - accuracy: 0.6875
# Epoch 14/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6500 - accuracy: 0.6784
# Epoch 15/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6315 - accuracy: 0.6784
# Epoch 16/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6354 - accuracy: 0.6849
# Epoch 17/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6717 - accuracy: 0.6380
# Epoch 18/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6195 - accuracy: 0.6693
# Epoch 19/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.6339 - accuracy: 0.6758
# Epoch 20/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6115 - accuracy: 0.7122
# Epoch 21/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6074 - accuracy: 0.6901
# Epoch 22/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6021 - accuracy: 0.6849
# Epoch 23/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6326 - accuracy: 0.6927
# Epoch 24/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5905 - accuracy: 0.7031
# Epoch 25/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5993 - accuracy: 0.6888
# Epoch 26/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6024 - accuracy: 0.6966
# Epoch 27/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5931 - accuracy: 0.6927
# Epoch 28/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6018 - accuracy: 0.6823
# Epoch 29/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5978 - accuracy: 0.6927
# Epoch 30/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.6349 - accuracy: 0.6771
# Epoch 31/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.6057 - accuracy: 0.7044
# Epoch 32/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6119 - accuracy: 0.6953
# Epoch 33/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5762 - accuracy: 0.7083
# Epoch 34/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5636 - accuracy: 0.7018
# Epoch 35/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6094 - accuracy: 0.6862
# Epoch 36/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5708 - accuracy: 0.7174
# Epoch 37/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5673 - accuracy: 0.7161
# Epoch 38/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5808 - accuracy: 0.7005
# Epoch 39/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5744 - accuracy: 0.7096
# Epoch 40/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5834 - accuracy: 0.7057
# Epoch 41/100
# 154/154 [==============================] - 1s 7ms/step - loss: 0.5800 - accuracy: 0.7096
# Epoch 42/100
# 154/154 [==============================] - 1s 4ms/step - loss: 0.5883 - accuracy: 0.7031
# Epoch 43/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5862 - accuracy: 0.7161
# Epoch 44/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5753 - accuracy: 0.6992
# Epoch 45/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5640 - accuracy: 0.7122
# Epoch 46/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5943 - accuracy: 0.6914
# Epoch 47/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5668 - accuracy: 0.7044
# Epoch 48/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6024 - accuracy: 0.6823
# Epoch 49/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5637 - accuracy: 0.7188
# Epoch 50/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5902 - accuracy: 0.6992
# Epoch 51/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5836 - accuracy: 0.7083
# Epoch 52/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5899 - accuracy: 0.6979
# Epoch 53/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5768 - accuracy: 0.7083
# Epoch 54/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5663 - accuracy: 0.7227
# Epoch 55/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5754 - accuracy: 0.7018
# Epoch 56/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.6063 - accuracy: 0.7122
# Epoch 57/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5810 - accuracy: 0.7122
# Epoch 58/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5515 - accuracy: 0.7148
# Epoch 59/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5638 - accuracy: 0.7396
# Epoch 60/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5766 - accuracy: 0.6992
# Epoch 61/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5448 - accuracy: 0.7214
# Epoch 62/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5506 - accuracy: 0.7044
# Epoch 63/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5558 - accuracy: 0.7201
# Epoch 64/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5519 - accuracy: 0.7161
# Epoch 65/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5526 - accuracy: 0.7201
# Epoch 66/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5666 - accuracy: 0.7096
# Epoch 67/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5558 - accuracy: 0.7201
# Epoch 68/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5465 - accuracy: 0.7318
# Epoch 69/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5627 - accuracy: 0.7188
# Epoch 70/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5574 - accuracy: 0.7188
# Epoch 71/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5490 - accuracy: 0.7253
# Epoch 72/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5670 - accuracy: 0.7148
# Epoch 73/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5508 - accuracy: 0.7148
# Epoch 74/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5633 - accuracy: 0.7227
# Epoch 75/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5589 - accuracy: 0.7161
# Epoch 76/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5466 - accuracy: 0.7214
# Epoch 77/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5452 - accuracy: 0.7214
# Epoch 78/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5436 - accuracy: 0.7266
# Epoch 79/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5410 - accuracy: 0.7279
# Epoch 80/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5495 - accuracy: 0.7331
# Epoch 81/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5383 - accuracy: 0.7331
# Epoch 82/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5525 - accuracy: 0.7435
# Epoch 83/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5503 - accuracy: 0.7435
# Epoch 84/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5506 - accuracy: 0.7227
# Epoch 85/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5366 - accuracy: 0.7344
# Epoch 86/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5422 - accuracy: 0.7292
# Epoch 87/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5744 - accuracy: 0.7135
# Epoch 88/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5462 - accuracy: 0.7227
# Epoch 89/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5334 - accuracy: 0.7253
# Epoch 90/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5509 - accuracy: 0.7305
# Epoch 91/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5348 - accuracy: 0.7331
# Epoch 92/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5360 - accuracy: 0.7396
# Epoch 93/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5657 - accuracy: 0.7188
# Epoch 94/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5384 - accuracy: 0.7370
# Epoch 95/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5338 - accuracy: 0.7370
# Epoch 96/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5439 - accuracy: 0.7253
# Epoch 97/100
# 154/154 [==============================] - 1s 3ms/step - loss: 0.5361 - accuracy: 0.7344
# Epoch 98/100
# 154/154 [==============================] - 0s 3ms/step - loss: 0.5283 - accuracy: 0.7357
# Epoch 99/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5425 - accuracy: 0.7318
# Epoch 100/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.5345 - accuracy: 0.7318
