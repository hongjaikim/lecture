# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/lol.csv',sep='\t')
# print(data)

# print(data.head())

# print(data.shape)

# print(data.columns)

# print(data.columns[5])

# print(data.iloc[:,5].dtype)

# print(data.index)

# print(data.iloc[2,5])

# %%
import pandas as pd
data =pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/Jeju.csv',encoding='CP949')
# print(data)

# print(data.tail(3))

# print(data.select_dtypes(exclude=object).columns)

# print(data.select_dtypes(include=object).columns)

# print(data.isnull().sum())

# print(data.info())

# print(data.describe())

# print(data['거주인구'])

# desc = data['평균 속도'].describe()
# print(desc['75%']-desc['25%'])

# print(data['평균 속도'].quantile(0.75)-data['평균 속도'].quantile(0.25))

# print(len(data['읍면동명'].unique()))

# print(data.읍면동명.nunique())
# print(data['읍면동명'].nunique())

# print(data.읍면동명.unique())

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/chipo.csv')
# print(data)

# print(data[data['quantity']==3].head())

# print(data.loc[data['quantity']==3].head().reset_index(drop=True))

# print(data[['quantity','item_price']])

data['new_price'] = data['item_price'].str[1:].astype('float')
# print(data['new_price'])

# print(len(data[data['new_price']<=5]))

# print(data[data['item_name']=='Chicken Salad Bowl'].reset_index(drop=True))

# print(data[(data['new_price']<=9)&(data['item_name']=='Chicken Salad Bowl')])

# print(data.sort_values('new_price',ascending=True).reset_index(drop=True).head())

# print(data[data['item_name'].str.contains('Chips')].head())

# print(data.iloc[:,1::2])

# print(data.sort_values(by='new_price',ascending=False).reset_index(drop=True).head())

# print(data[(data['item_name']=='Steak Salad') |( data['item_name']=='Bowl')].head())

# print(data[(data['item_name']=='Steak Salad')|(data['item_name']=='Bowl')].drop_duplicates('item_name'))

# print(data[(data['item_name']=='Steak Salad')|(data['item_name']=='Bowl')].drop_duplicates('item_name',keep='last'))

# print(data[data['new_price']>=data['new_price'].mean()].head())

data.loc[data['item_name']=='Izze','item_name']='Fizzy Lizzy'
# print(data.head())

# print(data['choice_description'].isnull().sum())

data.loc[data['choice_description'].isnull(),'choice_description']='NoData'
# print(data.head())

# print(data[data['choice_description'].str.contains('Black')].head())

# print(len(data[~data['choice_description'].str.contains('Vegetables')]))

# print(data[data['item_name'].str.startswith('N')].head())

# print(data[data['item_name'].str.len()>=15].head())

# print(len(data[data.new_price.isin([1.69, 2.39, 3.39, 4.45, 9.25, 10.98, 11.75, 16.98])]))

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/AB_NYC_2019.csv')
# print(df.head())

# print(df['host_name'].value_counts().sort_index().head())

a = df.groupby('host_name').size().to_frame().rename(columns={0:'counts'}).sort_values('counts',ascending=False)
# print(a.head())

# print(df.groupby(['neighbourhood_group','neighbourhood'],as_index=False).size().head())

# print(df.groupby(['neighbourhood_group','neighbourhood']).size().groupby('neighbourhood_group').max())

# print(df.groupby(['neighbourhood_group'])['price'].agg(['mean','var','min','max']))
# print(df[['neighbourhood_group','price']].groupby('neighbourhood_group').agg(['mean','var','min','max']))

# print(df[['neighbourhood_group','reviews_per_month']].groupby('neighbourhood_group').agg(['mean','var','max','min']))

# print(df.groupby(['neighbourhood','neighbourhood_group'])['price'].mean())

# print(df.groupby(['neighbourhood','neighbourhood_group']).price.mean().unstack())

# print(df.groupby(['neighbourhood','neighbourhood_group']).price.mean().unstack().fillna(-999))

# print(df[df.neighbourhood_group=='Queens'].groupby('neighbourhood').price.agg(['mean','var','max','min']))

a = df.groupby(['neighbourhood_group','room_type']).size().unstack()
a[:] = a.values/a.sum(axis=1).values.reshape(-1,1)
# print(a)

# %% [markdown]
# Q56

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/BankChurnersUp.csv',index_col=0)

# print(df.shape)

# print(df['Income_Category'].unique())
# dic = {'Unknown':'N',
#        'Less than $40K':'a',
#        '$40K - $60K':'b',
#        '$60K - $80K':'c',
#        '$80K - $120K':'d',
#        '$120K +':'e'
# }
# df['newIncome'] = df['Income_Category'].map(lambda x:dic[x])
# df['newIncome'] = df['Income_Category'].replace('Unknown','N').replace('Less than $40K','a').replace('$40K - $60K','b').replace('$60K - $80K','c').replace('$80K - $120K','d').replace('$120K +','e')
# print(df.head())

def changeCategory(x):
  if x=='Unknown':
    return 'N'
  elif x =='Less than $40K':
    return 'a'
  elif x=='$40K - $60K':
    return 'b'
  elif x=='$60K - $80K':
    return 'c'
  elif x=='$80K - $120K':
    return 'd'
  elif x=='$120K +':
    return 'e'
df['newIncome'] = df['Income_Category'].apply(changeCategory)
# print(df.head())

df['AgeState'] = df['Customer_Age']//10*10
# print(df)
# print(df['AgeState'].value_counts().sort_index())

df['newEduLevel'] = df['Education_Level'].map(lambda x:1 if 'Graduate' in x else 0)
# print(df['newEduLevel'].value_counts())

df['newLimit'] = df['Credit_Limit'].map(lambda x: 1 if x>=4500 else 0)
# print(df['newLimit'].value_counts())

def check(x):
  if x.Marital_Status == 'Married' and x['Card_Category']=='Platinum':
    return 1
  else:
    return 0
df['newState'] = df.apply(check,axis=1)
# print(df.newState.value_counts())

df['Gender'] = df['Gender'].map(lambda x:'male' if x=='M' else 'female')
# print(df['Gender'].value_counts())

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/timeTest.csv',index_col=False)
# print(df.info())

df['Yr_Mo_Dy']=pd.to_datetime(df['Yr_Mo_Dy'])
# print(df.iloc[:,0])

# print(df['Yr_Mo_Dy'].dt.year.unique())

def fix(x):
  import datetime
  year = x.year-100 if x.year>=2061 else x.year
  return pd.to_datetime(datetime.date(year,x.month,x.day))
df['Yr_Mo_Dy'] = df['Yr_Mo_Dy'].apply(fix)
# print(df.iloc[:,0])

# print(df.groupby(df['Yr_Mo_Dy'].dt.year).mean())

df['weekday'] = df['Yr_Mo_Dy'].dt.weekday
# print(df['weekday'])

df['WeekCheck'] = df['weekday'].map(lambda x: 1 if x in (5,6) else 0)
# print(df['WeekCheck'])

# print(df.groupby(df['Yr_Mo_Dy'].dt.month).mean())

df = df.fillna(method='ffill').fillna(method='bfill')
# print(df.isnull().sum())

# print(df.groupby(df['Yr_Mo_Dy'].dt.to_period('M')).mean())

# print(df['RPT'].diff())

# print(df[['RPT','VAL']].rolling(7).mean().head(10))

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/seoul_pm.csv')
# print(df)

def change(x):
  import datetime
  hour = x.split(':')[1]
  date = x.split(':')[0]

  if hour  =='24':
    hour = '00:00:00'
    finaldate = pd.to_datetime(date+' '+hour)+datetime.timedelta(days=1)
  else:
    hour = hour +':00:00'
    finaldate = pd.to_datetime(date+' '+hour)
  return finaldate
df.iloc[:,0] = df.iloc[:,0].apply(change)
# print(df)

df['dayName'] = df.iloc[:,0].dt.day_name()
# print(df['dayName'])

# print(df.groupby(['dayName','PM10등급'],as_index=False).size())

# if len(df.iloc[:,0].diff().unique())==2:
#   print(True)
# else:
#   print(False)

# print(df.groupby(df.iloc[:,0].dt.hour).mean().iloc[[10,22],[0]])

# print(df.resample('W').agg(['min','max','mean','std']))

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/under5MortalityRate.csv')
df.drop(['Indicator'],axis=1,inplace=True)
df.iloc[:,-1] = df.iloc[:,-1].map(lambda x:float(x.split('[')[0]))
# print(df)

data = df[(df.Period>=2015)&(df.Dim1=='Both sexes')]
# print(df[(df.Period>=2015)&(df.Dim1=='Both sexes')])

# print(data.pivot(index='Location',columns='Period',values='First Tooltip'))

# print(df.pivot_table(index='Dim1',columns='Period',values='First Tooltip',aggfunc='mean'))
# Out:
# Period            1950        1951        1952        1953        1954  \
# Dim1
# Both sexes  147.700816  155.537544  157.811094  156.147206  154.539857
# Female      140.909796  149.210175  151.516094  150.250882  148.688286
# Male        154.151224  161.538246  163.760781  161.742059  160.081000
#
# Period            1955        1956        1957        1958        1959  ...  \
# Dim1                                                                    ...
# Both sexes  155.797179  159.241163  156.170114  150.813222  150.574000  ...
# Female      149.843205  153.048721  149.988295  144.719667  144.451474  ...
# Male        161.456923  165.089535  162.015000  156.573556  156.375053  ...
#
# Period           2010       2011       2012       2013       2014       2015  \
# Dim1
# Both sexes  37.718488  35.573663  34.290988  33.099360  32.053314  31.012093
# Female      34.953023  32.877616  31.654070  30.521337  29.524302  28.544360
# Male        40.340174  38.140291  36.793081  35.543663  34.446105  33.354302
#
# Period           2016       2017       2018       2019
# Dim1
# Both sexes  29.956337  29.030465  28.083837  27.191744
# Female      27.542035  26.675291  25.782616  24.945349
# Male        32.242616  31.273198  30.283023  29.350349
#
# [3 rows x 70 columns]

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/winter.csv')
# print(df)

data=df[df.Country=='KOR']
# print(df[df.Country=='KOR'])

# print(data.pivot_table(index='Year',columns='Medal',aggfunc='size').fillna(0))

# print(df.pivot_table(index='Sport',columns='Gender',aggfunc='size'))

# print(df.pivot_table(index='Discipline',columns='Medal',aggfunc='size'))

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/mergeTEst.csv',index_col=0)
# print(df)

df1 = df.iloc[:4,:]
df2 = df.iloc[4:,:]

# print(pd.concat([df1,df2],axis=0))

df3 = df.iloc[:2,:4]
df4 = df.iloc[5:,3:]

# print(pd.concat([df3,df4],axis=0,join='inner'))

# print(pd.concat([df3,df4],join='outer').fillna(0))

df5 = df.T.iloc[:7,:3]
df6 = df.T.iloc[6:,2:5]

# print(pd.merge(df5,df6,on='Algeria',how='inner'))

# print(pd.merge(df5,df6,on='Algeria',how='outer'))
# Out:
# Location  Afghanistan  Albania  Algeria  Andorra  Angola
# 0              64.023   11.803   23.540      NaN     NaN
# 1              61.640   10.807   22.907      NaN     NaN
# 2              59.367    9.943   22.450      NaN     NaN
# 3              57.170    9.267   22.117      NaN     NaN
# 4              55.080    8.790   21.850      NaN     NaN
# 5              53.107    8.493   21.587      NaN     NaN
# 6              51.267    8.363   21.257    3.187  55.510
# 7                 NaN      NaN   20.850    3.060  53.460
# 8                 NaN      NaN   20.407    2.933  51.757
# 9                 NaN      NaN   19.930    2.827  50.093
